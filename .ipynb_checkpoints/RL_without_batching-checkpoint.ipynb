# %% [markdown]
# ## Import

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete
from gym import spaces
import numpy as np
import random
import os

import pandas as pd
from stable_baselines3 import PPO, DQN, A2C
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# Sunday - 1
#
# Saturday - 7

# %% [markdown]
# ## Getting files for each day of the month and storing in pd_refs

# %%
files = os.listdir("DayCSV")

# %%
pd_refs = []

# %%
for i in files:
    pd_refs.append(pd.read_csv("DayCSV\\"+i))

# %% [markdown]
# ## Environment - 1

# %% [markdown]
# ### State
# The data was modeled to function like an environment where the state space of the agent would be an array consisting of
# - Energy consumption of previous hour
# - Value of the previous hour
# - Day number  (1 indicates Sunday and 7 indicates Saturday)
#
# ### Action
# Using the given state space, in this environment the agent would be required to predict the fall, rise or constant energy requirement for the next day, giving the agent 3 possible actions - Increase, Decrease and Constant.
#
# ### Reward
# For a correct prediction of the change in power consumption, the agent would be given a reward of +10 whereas a wrong prediction would give the agent a reward of -100.
#
# In cases where the agent chose the action as constant, if the power consumption of next day is within 5%, then the agent is given a positive reward else it is given a negative reward. This condition is represented as follows
#
# $0.95 * Energy_t <= Energy_{t+1}<= 1.05 * Energy_t$
#
# where $t$ is timestep t.

# %%
class PowerPredEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3) # Increase, Decrease, keep same
        self.observation_space = Box(low=np.array([0,0,1]), high=np.array([23,63000, 7]), dtype=np.int32) ## [Hour of day, Power in MW, Day of week]
        self.day = 0 #Current day - Opens the day's CSV file
        self.hour = 0 # Hour - Row number of the CSV
        self.state = [self.hour, pd_refs[self.day].loc[self.hour,"MW"], pd_refs[self.day].loc[self.hour,"Day"]] ## State of the environment
        
    def get_current_power(self):
        ## Returns the power consumption of the day stored in self.day
        return pd_refs[self.day].loc[self.hour,"MW"]

    def next_day(self):
        ## Changes the day to next day and checks if all CSV files have been read
        self.day += 1
        if(self.day == 30):
            return True
        self.hour = 0
        self.state = [self.hour, self.get_current_power(), pd_refs[self.day].loc[self.hour,"Day"]]
        return False
        
    def step(self, action):
        actual_power = pd_refs[self.day].loc[self.hour+1,"MW"] # Actual power at hour t+1
        prev_power = self.state[1] # Power of previous day
        done = False
        reward = 0
        ## 0 - Increase, 1 - Decrease, 2 - Same
        if(action == 0):
            if(actual_power > prev_power):
                ## Correct prediction of increase in power demand
                reward = 10
            else:
                reward = -100
        elif(action == 1):
            if(actual_power < prev_power):
                ## Correct prediction of decrease in power demand
                reward = 10
            else:
                reward = -100
        elif(action == 2):
            if(0.95*prev_power < actual_power < 1.05 * prev_power):
                ## Correct prediction of constant power demand
                ## The power is within 5% of the previous day's power consumption
                reward = 10
            else:
                reward = -100
        self.hour +=1 # Increase the hour count
        done = False
        if(self.hour == 23):
            ## If all hours of the day are completed, move to next file
            done = self.next_day()
        if not done:
            ## Check if all files are read, if not continue 
            self.state = [self.hour, self.get_current_power(), pd_refs[self.day].loc[self.hour,"Day"]]
        info = {
            "day":self.day+1,
            "reward":reward,
            "hour":self.hour-1,
            "prev":prev_power,
            "predicted":action,
            "actual":actual_power
        }
        return self.state, reward, False, done, info
    
    def render(self):
        pass
    
    def reset(self):
        ## Reset the values
        self.day = 0
        self.hour = 0
        self.state = [self.hour, self.get_current_power(), pd_refs[self.day].loc[self.hour,"Day"]]
        info = {
                    "day":self.day+1,
                    "reward":reward,
                    "hour":self.hour-1,
                    "predicted":action,
                }
        return self.state, info

# %%
env = PowerPredEnv()

# %% [markdown]
# ## Result using random action selection for 5 episodes

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, _, done, info = env.step(action)
        score += reward
        # if(reward > 0):
        #     print(reward, info)
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-26100
# Episode:2 Score:-27860
# Episode:3 Score:-27530
# Episode:4 Score:-26210
# Episode:5 Score:-27970

# %% [markdown]
# ## PPO

# %%
log_path = os.path.join('Training', 'logs')
model1 = PPO('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model1.learn(total_timesteps=1000000)
# Out:
# Logging to Training\logs\PPO_7
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 690       |
# |    ep_rew_mean     | -2.68e+04 |
# | time/              |           |
# |    fps             | 499       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -2.58e+04   |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013047331 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 4.37e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 690        |
# |    ep_rew_mean          | -2.59e+04  |
# | time/                   |            |
# |    fps                  | 379        |
# |    iterations           | 3          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01355991 |
# |    clip_fraction        | 0.0838     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.71e+05   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00856   |
# |    value_loss           | 3.7e+05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -2.54e+04   |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017916061 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 3.8e+05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 690        |
# |    ep_rew_mean          | -2.47e+04  |
# | time/                   |            |
# |    fps                  | 361        |
# |    iterations           | 5          |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01563924 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.901     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.56e+05   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 3.21e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -2.42e+04   |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 6           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010967148 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00655    |
# |    value_loss           | 2.88e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -2.37e+04   |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 7           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008569718 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.715      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 2.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -2.32e+04   |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 8           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005462786 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+05     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 2.59e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.27e+04    |
# | time/                   |              |
# |    fps                  | 352          |
# |    iterations           | 9            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0052330624 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.558       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 2.2e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.23e+04    |
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 10           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0037582265 |
# |    clip_fraction        | 0.00908      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 2.25e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 690        |
# |    ep_rew_mean          | -2.2e+04   |
# | time/                   |            |
# |    fps                  | 350        |
# |    iterations           | 11         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00310695 |
# |    clip_fraction        | 0.027      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.398     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.77e+04   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00281   |
# |    value_loss           | 2.1e+05    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.17e+04    |
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 12           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0021912497 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.347       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 2.05e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.15e+04    |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 13           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0022215694 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.83e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 2.06e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.12e+04    |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 14           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0012232728 |
# |    clip_fraction        | 0.00786      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 2.04e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.1e+04      |
# | time/                   |               |
# |    fps                  | 348           |
# |    iterations           | 15            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00026362357 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.236        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.04e+05      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -5.48e-05     |
# |    value_loss           | 2e+05         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.09e+04     |
# | time/                   |               |
# |    fps                  | 348           |
# |    iterations           | 16            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00065231917 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.212        |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.86e+04      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000198     |
# |    value_loss           | 1.94e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.07e+04    |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 17           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0010144333 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.174       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 1.97e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.06e+04     |
# | time/                   |               |
# |    fps                  | 347           |
# |    iterations           | 18            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00054937485 |
# |    clip_fraction        | 0.00479       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.15         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.39e+04      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000806     |
# |    value_loss           | 1.9e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.04e+04     |
# | time/                   |               |
# |    fps                  | 347           |
# |    iterations           | 19            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00057403534 |
# |    clip_fraction        | 0.0103        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.125        |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.5e+04       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00179      |
# |    value_loss           | 1.84e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.03e+04     |
# | time/                   |               |
# |    fps                  | 347           |
# |    iterations           | 20            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00026564693 |
# |    clip_fraction        | 0.00327       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.114        |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.85e+04      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.001        |
# |    value_loss           | 1.86e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.02e+04     |
# | time/                   |               |
# |    fps                  | 346           |
# |    iterations           | 21            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00045322182 |
# |    clip_fraction        | 0.00249       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.103        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.04e+04      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00062      |
# |    value_loss           | 1.82e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.01e+04     |
# | time/                   |               |
# |    fps                  | 346           |
# |    iterations           | 22            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 1.2286298e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0953       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+05      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -1.82e-05     |
# |    value_loss           | 1.79e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2e+04        |
# | time/                   |               |
# |    fps                  | 346           |
# |    iterations           | 23            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00022148193 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0903       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.08e+04      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000276     |
# |    value_loss           | 1.78e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.99e+04     |
# | time/                   |               |
# |    fps                  | 343           |
# |    iterations           | 24            |
# |    time_elapsed         | 143           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00040775878 |
# |    clip_fraction        | 0.00527       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0735       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.38e+04      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.001        |
# |    value_loss           | 1.79e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.98e+04     |
# | time/                   |               |
# |    fps                  | 343           |
# |    iterations           | 25            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 2.4713605e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0708       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.69e+04      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -5.69e-05     |
# |    value_loss           | 1.81e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.97e+04     |
# | time/                   |               |
# |    fps                  | 343           |
# |    iterations           | 26            |
# |    time_elapsed         | 155           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00019183321 |
# |    clip_fraction        | 0.00225       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0789       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.59e+04      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000388     |
# |    value_loss           | 1.77e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.96e+04     |
# | time/                   |               |
# |    fps                  | 343           |
# |    iterations           | 27            |
# |    time_elapsed         | 161           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00028211199 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0763       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.05e+04      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000282     |
# |    value_loss           | 1.82e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.96e+04    |
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 28           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 8.841269e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0658      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.09e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000131    |
# |    value_loss           | 1.83e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.95e+04     |
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 29            |
# |    time_elapsed         | 173           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 4.1409774e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0642       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.86e+04      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -5.01e-05     |
# |    value_loss           | 1.76e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.95e+04     |
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 30            |
# |    time_elapsed         | 179           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 1.8030405e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0657       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.54e+04      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 4.8e-06       |
# |    value_loss           | 1.71e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.94e+04    |
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 31           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 9.693613e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0652      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.42e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 5.15e-06     |
# |    value_loss           | 1.74e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.94e+04     |
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 32            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00013277843 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0602       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.98e+04      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000235     |
# |    value_loss           | 1.72e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.93e+04   |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 33          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 9.51502e-05 |
# |    clip_fraction        | 0.000146    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0515     |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.49e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000256   |
# |    value_loss           | 1.7e+05     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.93e+04     |
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 34            |
# |    time_elapsed         | 203           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00014933478 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0422       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.86e+04      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000693     |
# |    value_loss           | 1.71e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.9e+04     |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 35           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 7.054777e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0368      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.74e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000147    |
# |    value_loss           | 1.69e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.88e+04    |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 36           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 8.954143e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0339      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.7e+04      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -7.18e-05    |
# |    value_loss           | 1.65e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.85e+04    |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 37           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 7.624144e-05 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0372      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.41e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000285    |
# |    value_loss           | 1.62e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.84e+04    |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 38           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 2.567182e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0408      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.19e+04     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -7.21e-05    |
# |    value_loss           | 1.65e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.82e+04    |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 39           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 5.679566e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0405      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.87e+04     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00021     |
# |    value_loss           | 1.68e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.81e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 40            |
# |    time_elapsed         | 240           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.3168668e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0395       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.32e+04      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -6.14e-05     |
# |    value_loss           | 1.7e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.8e+04      |
# | time/                   |               |
# |    fps                  | 339           |
# |    iterations           | 41            |
# |    time_elapsed         | 247           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 3.2447948e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0425       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.14e+04      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -8.81e-05     |
# |    value_loss           | 1.67e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.8e+04      |
# | time/                   |               |
# |    fps                  | 339           |
# |    iterations           | 42            |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00010012038 |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0478       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.95e+04      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000139     |
# |    value_loss           | 1.67e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.79e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 43            |
# |    time_elapsed         | 259           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 2.9392744e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0483       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.86e+04      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -5.17e-05     |
# |    value_loss           | 1.63e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.79e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 44            |
# |    time_elapsed         | 264           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00013494148 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.042        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.79e+04      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000303     |
# |    value_loss           | 1.65e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.79e+04    |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 45           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 6.149785e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.039       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.37e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -2.13e-05    |
# |    value_loss           | 1.6e+05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.78e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 46            |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.0797521e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0397       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.6e+04       |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -5.19e-07     |
# |    value_loss           | 1.6e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.78e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 47            |
# |    time_elapsed         | 282           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 1.5408732e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0394       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.12e+04      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -1.51e-05     |
# |    value_loss           | 1.62e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.78e+04    |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 48           |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 3.329324e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0412      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.88e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -7.64e-05    |
# |    value_loss           | 1.58e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.78e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 49            |
# |    time_elapsed         | 294           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 5.8329926e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0408       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.62e+04      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000145     |
# |    value_loss           | 1.57e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 50            |
# |    time_elapsed         | 300           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 4.6325265e-05 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0414       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.6e+04       |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000222     |
# |    value_loss           | 1.56e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 51            |
# |    time_elapsed         | 306           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00016498292 |
# |    clip_fraction        | 0.0019        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.038        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.69e+04      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000571     |
# |    value_loss           | 1.56e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 52            |
# |    time_elapsed         | 312           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 4.2394764e-05 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0376       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.81e+04      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000395     |
# |    value_loss           | 1.55e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 53            |
# |    time_elapsed         | 318           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 4.8041897e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0365       |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.85e+04      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -8.02e-05     |
# |    value_loss           | 1.53e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 340           |
# |    iterations           | 54            |
# ...
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 471       |
# |    time_elapsed         | 2954      |
# |    total_timesteps      | 964608    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.4e+04   |
# |    n_updates            | 4700      |
# |    policy_gradient_loss | -6.52e-10 |
# |    value_loss           | 2.51e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 472       |
# |    time_elapsed         | 2960      |
# |    total_timesteps      | 966656    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.1e+04   |
# |    n_updates            | 4710      |
# |    policy_gradient_loss | 3.81e-10  |
# |    value_loss           | 2.53e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 473       |
# |    time_elapsed         | 2967      |
# |    total_timesteps      | 968704    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.92e+03  |
# |    n_updates            | 4720      |
# |    policy_gradient_loss | -3.43e-10 |
# |    value_loss           | 2.56e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 474       |
# |    time_elapsed         | 2974      |
# |    total_timesteps      | 970752    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.15e+04  |
# |    n_updates            | 4730      |
# |    policy_gradient_loss | 4.12e-10  |
# |    value_loss           | 2.55e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 475       |
# |    time_elapsed         | 2980      |
# |    total_timesteps      | 972800    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.12e+04  |
# |    n_updates            | 4740      |
# |    policy_gradient_loss | 1.2e-09   |
# |    value_loss           | 2.54e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 476       |
# |    time_elapsed         | 2986      |
# |    total_timesteps      | 974848    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.39e+04  |
# |    n_updates            | 4750      |
# |    policy_gradient_loss | 5.82e-12  |
# |    value_loss           | 2.52e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 477       |
# |    time_elapsed         | 2993      |
# |    total_timesteps      | 976896    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.49e+04  |
# |    n_updates            | 4760      |
# |    policy_gradient_loss | 1.4e-10   |
# |    value_loss           | 2.54e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 478       |
# |    time_elapsed         | 2999      |
# |    total_timesteps      | 978944    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.35e+04  |
# |    n_updates            | 4770      |
# |    policy_gradient_loss | 7.89e-10  |
# |    value_loss           | 2.51e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 479       |
# |    time_elapsed         | 3005      |
# |    total_timesteps      | 980992    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.19e+04  |
# |    n_updates            | 4780      |
# |    policy_gradient_loss | 7.28e-11  |
# |    value_loss           | 2.45e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 480       |
# |    time_elapsed         | 3012      |
# |    total_timesteps      | 983040    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.17e+04  |
# |    n_updates            | 4790      |
# |    policy_gradient_loss | 2.12e-10  |
# |    value_loss           | 2.44e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 481       |
# |    time_elapsed         | 3019      |
# |    total_timesteps      | 985088    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.23e+04  |
# |    n_updates            | 4800      |
# |    policy_gradient_loss | 2.15e-10  |
# |    value_loss           | 2.48e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 482       |
# |    time_elapsed         | 3025      |
# |    total_timesteps      | 987136    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.23e+04  |
# |    n_updates            | 4810      |
# |    policy_gradient_loss | 8.44e-10  |
# |    value_loss           | 2.54e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 483       |
# |    time_elapsed         | 3031      |
# |    total_timesteps      | 989184    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000306 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.55e+04  |
# |    n_updates            | 4820      |
# |    policy_gradient_loss | -1.54e-10 |
# |    value_loss           | 2.54e+04  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 326           |
# |    iterations           | 484           |
# |    time_elapsed         | 3038          |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 1.1436234e-05 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000355     |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.41e+04      |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -8.58e-05     |
# |    value_loss           | 2.54e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 326           |
# |    iterations           | 485           |
# |    time_elapsed         | 3044          |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 4.4237822e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000355     |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+04      |
# |    n_updates            | 4840          |
# |    policy_gradient_loss | 1.66e-06      |
# |    value_loss           | 2.56e+04      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 486       |
# |    time_elapsed         | 3051      |
# |    total_timesteps      | 995328    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000355 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.04e+04  |
# |    n_updates            | 4850      |
# |    policy_gradient_loss | -4.12e-10 |
# |    value_loss           | 2.57e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 487       |
# |    time_elapsed         | 3057      |
# |    total_timesteps      | 997376    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000355 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.46e+04  |
# |    n_updates            | 4860      |
# |    policy_gradient_loss | 1.35e-09  |
# |    value_loss           | 2.54e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 488       |
# |    time_elapsed         | 3063      |
# |    total_timesteps      | 999424    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000355 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.12e+04  |
# |    n_updates            | 4870      |
# |    policy_gradient_loss | -1.12e-09 |
# |    value_loss           | 2.53e+04  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 489       |
# |    time_elapsed         | 3070      |
# |    total_timesteps      | 1001472   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000355 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.43e+04  |
# |    n_updates            | 4880      |
# |    policy_gradient_loss | 2.63e-10  |
# |    value_loss           | 2.56e+04  |
# ---------------------------------------

# %% [markdown]
# PPO
#
# Average reward after 1,000,000 timesteps = -17600
#
# ![image.png](attachment:9c204888-1f2f-499b-8267-50ace9e9ec2f.png)
#
# The PPO model also stagnated in terms of performance and showed minor improvement on further training

# %% [markdown]
# ## DQN

# %%
model2 = DQN('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model2.learn(total_timesteps = 1000000)
# Out:
# Logging to Training\logs\DQN_3
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.65e+04 |
# |    exploration_rate | 0.974     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 3967      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 2760      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.66e+04 |
# |    exploration_rate | 0.948     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 5368      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 5520      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6043     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8280     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.71e+04 |
# |    exploration_rate | 0.895     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 6576      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 11040     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6910     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 7114     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16560    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.71e+04 |
# |    exploration_rate | 0.816     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 7302      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 19320     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7455     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22080    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.764     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 7580      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 24840     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.738     |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 7674      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 27600     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.712     |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 7752      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 30360     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.685     |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 7793      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 33120     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.659     |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 7854      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 35880     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.633     |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 7917      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 38640     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.607     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 7948      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 41400     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.58      |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 7975      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 44160     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.554     |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 7991      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 46920     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.528     |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 8020      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 49680     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.66e+04 |
# |    exploration_rate | 0.502     |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 5313      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 52440     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 92.7      |
# |    n_updates        | 609       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.65e+04 |
# |    exploration_rate | 0.476     |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 4053      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 55200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 135       |
# |    n_updates        | 1299      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.63e+04 |
# |    exploration_rate | 0.449     |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 3353      |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 57960     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 81.2      |
# |    n_updates        | 1989      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.62e+04 |
# |    exploration_rate | 0.423     |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 2821      |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 60720     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 96.6      |
# |    n_updates        | 2679      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.61e+04 |
# |    exploration_rate | 0.397     |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 2375      |
# |    time_elapsed     | 26        |
# |    total_timesteps  | 63480     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 89.1      |
# |    n_updates        | 3369      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.6e+04 |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2140     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 66240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 99.8     |
# |    n_updates        | 4059     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.59e+04 |
# |    exploration_rate | 0.345     |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 1961      |
# |    time_elapsed     | 35        |
# |    total_timesteps  | 69000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 98        |
# |    n_updates        | 4749      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.58e+04 |
# |    exploration_rate | 0.318     |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 1801      |
# |    time_elapsed     | 39        |
# |    total_timesteps  | 71760     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 99.6      |
# |    n_updates        | 5439      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.56e+04 |
# |    exploration_rate | 0.292     |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 1677      |
# |    time_elapsed     | 44        |
# |    total_timesteps  | 74520     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 126       |
# |    n_updates        | 6129      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.53e+04 |
# |    exploration_rate | 0.266     |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 1583      |
# |    time_elapsed     | 48        |
# |    total_timesteps  | 77280     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 83.4      |
# |    n_updates        | 6819      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.51e+04 |
# |    exploration_rate | 0.24      |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 1500      |
# |    time_elapsed     | 53        |
# |    total_timesteps  | 80040     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 111       |
# |    n_updates        | 7509      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.49e+04 |
# |    exploration_rate | 0.213     |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 1419      |
# |    time_elapsed     | 58        |
# |    total_timesteps  | 82800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 97.8      |
# |    n_updates        | 8199      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.46e+04 |
# |    exploration_rate | 0.187     |
# | time/               |           |
# |    episodes         | 124       |
# |    fps              | 1357      |
# |    time_elapsed     | 63        |
# |    total_timesteps  | 85560     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 103       |
# |    n_updates        | 8889      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.44e+04 |
# |    exploration_rate | 0.161     |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 1308      |
# |    time_elapsed     | 67        |
# |    total_timesteps  | 88320     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 92.6      |
# |    n_updates        | 9579      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.42e+04 |
# |    exploration_rate | 0.135     |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 1253      |
# |    time_elapsed     | 72        |
# |    total_timesteps  | 91080     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 92.9      |
# |    n_updates        | 10269     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.4e+04 |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1211     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 93840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 93.6     |
# |    n_updates        | 10959    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.37e+04 |
# |    exploration_rate | 0.0823    |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 1175      |
# |    time_elapsed     | 82        |
# |    total_timesteps  | 96600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 74.5      |
# |    n_updates        | 11649     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.36e+04 |
# |    exploration_rate | 0.0561    |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 1143      |
# |    time_elapsed     | 86        |
# |    total_timesteps  | 99360     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 85.2      |
# |    n_updates        | 12339     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.34e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 1115      |
# |    time_elapsed     | 91        |
# |    total_timesteps  | 102120    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 78.6      |
# |    n_updates        | 13029     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.31e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 1089      |
# |    time_elapsed     | 96        |
# |    total_timesteps  | 104880    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 91        |
# |    n_updates        | 13719     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.28e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 1067      |
# |    time_elapsed     | 100       |
# |    total_timesteps  | 107640    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 102       |
# |    n_updates        | 14409     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.26e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 1043      |
# |    time_elapsed     | 105       |
# |    total_timesteps  | 110400    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 121       |
# |    n_updates        | 15099     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.23e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 164       |
# |    fps              | 1022      |
# |    time_elapsed     | 110       |
# |    total_timesteps  | 113160    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 103       |
# |    n_updates        | 15789     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 1008      |
# |    time_elapsed     | 114       |
# |    total_timesteps  | 115920    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 142       |
# |    n_updates        | 16479     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.19e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 172       |
# |    fps              | 990       |
# |    time_elapsed     | 119       |
# |    total_timesteps  | 118680    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 132       |
# |    n_updates        | 17169     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.17e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 176       |
# |    fps              | 973       |
# |    time_elapsed     | 124       |
# |    total_timesteps  | 121440    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 101       |
# |    n_updates        | 17859     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.16e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 957       |
# |    time_elapsed     | 129       |
# |    total_timesteps  | 124200    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 83.9      |
# |    n_updates        | 18549     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.14e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 184       |
# |    fps              | 940       |
# |    time_elapsed     | 134       |
# |    total_timesteps  | 126960    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 80.8      |
# |    n_updates        | 19239     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.13e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 188       |
# |    fps              | 926       |
# |    time_elapsed     | 140       |
# |    total_timesteps  | 129720    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 88.9      |
# |    n_updates        | 19929     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.12e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 192       |
# |    fps              | 912       |
# |    time_elapsed     | 145       |
# |    total_timesteps  | 132480    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 114       |
# |    n_updates        | 20619     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.11e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 196       |
# |    fps              | 897       |
# |    time_elapsed     | 150       |
# |    total_timesteps  | 135240    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 80.3      |
# |    n_updates        | 21309     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.1e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 884      |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 138000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 124      |
# |    n_updates        | 21999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.1e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 873      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 140760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 126      |
# |    n_updates        | 22689    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.09e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 208       |
# |    fps              | 862       |
# |    time_elapsed     | 166       |
# |    total_timesteps  | 143520    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 74.5      |
# |    n_updates        | 23379     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.09e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 212       |
# |    fps              | 853       |
# |    time_elapsed     | 171       |
# |    total_timesteps  | 146280    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 86.7      |
# |    n_updates        | 24069     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.08e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 216       |
# |    fps              | 845       |
# |    time_elapsed     | 176       |
# |    total_timesteps  | 149040    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 91        |
# |    n_updates        | 24759     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.08e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 220       |
# |    fps              | 835       |
# |    time_elapsed     | 181       |
# |    total_timesteps  | 151800    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 111       |
# |    n_updates        | 25449     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.08e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 224       |
# |    fps              | 827       |
# |    time_elapsed     | 186       |
# |    total_timesteps  | 154560    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 91.6      |
# |    n_updates        | 26139     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 228       |
# |    fps              | 821       |
# |    time_elapsed     | 191       |
# |    total_timesteps  | 157320    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 103       |
# |    n_updates        | 26829     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 232       |
# |    fps              | 813       |
# |    time_elapsed     | 196       |
# |    total_timesteps  | 160080    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 113       |
# |    n_updates        | 27519     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 236       |
# |    fps              | 805       |
# |    time_elapsed     | 202       |
# |    total_timesteps  | 162840    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 83.7      |
# |    n_updates        | 28209     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 240       |
# |    fps              | 798       |
# |    time_elapsed     | 207       |
# |    total_timesteps  | 165600    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 101       |
# |    n_updates        | 28899     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 244       |
# |    fps              | 794       |
# |    time_elapsed     | 211       |
# |    total_timesteps  | 168360    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 70.4      |
# |    n_updates        | 29589     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 248       |
# |    fps              | 792       |
# |    time_elapsed     | 215       |
# |    total_timesteps  | 171120    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 136       |
# |    n_updates        | 30279     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 252       |
# |    fps              | 787       |
# |    time_elapsed     | 220       |
# |    total_timesteps  | 173880    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 99.7      |
# |    n_updates        | 30969     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 256       |
# |    fps              | 780       |
# |    time_elapsed     | 226       |
# |    total_timesteps  | 176640    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 90.2      |
# |    n_updates        | 31659     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 260       |
# |    fps              | 772       |
# |    time_elapsed     | 232       |
# |    total_timesteps  | 179400    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 66.4      |
# |    n_updates        | 32349     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 264       |
# |    fps              | 766       |
# |    time_elapsed     | 237       |
# |    total_timesteps  | 182160    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 119       |
# |    n_updates        | 33039     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 760       |
# |    time_elapsed     | 243       |
# |    total_timesteps  | 184920    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 77.3      |
# |    n_updates        | 33729     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 272       |
# |    fps              | 754       |
# |    time_elapsed     | 248       |
# |    total_timesteps  | 187680    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 93.1      |
# |    n_updates        | 34419     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 749       |
# |    time_elapsed     | 254       |
# |    total_timesteps  | 190440    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 88.1      |
# |    n_updates        | 35109     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 743       |
# |    time_elapsed     | 259       |
# |    total_timesteps  | 193200    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 92.3      |
# |    n_updates        | 35799     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 738       |
# |    time_elapsed     | 265       |
# |    total_timesteps  | 195960    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 95.6      |
# |    n_updates        | 36489     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 288       |
# |    fps              | 733       |
# |    time_elapsed     | 271       |
# |    total_timesteps  | 198720    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 96.5      |
# |    n_updates        | 37179     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 292       |
# |    fps              | 728       |
# |    time_elapsed     | 276       |
# |    total_timesteps  | 201480    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 96.5      |
# |    n_updates        | 37869     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.04e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 296       |
# |    fps              | 723       |
# |    time_elapsed     | 282       |
# |    total_timesteps  | 204240    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 135       |
# |    n_updates        | 38559     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 300       |
# |    fps              | 718       |
# |    time_elapsed     | 287       |
# |    total_timesteps  | 207000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 94.5      |
# |    n_updates        | 39249     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 304       |
# |    fps              | 716       |
# |    time_elapsed     | 292       |
# |    total_timesteps  | 209760    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 98.9      |
# |    n_updates        | 39939     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 308       |
# |    fps              | 713       |
# |    time_elapsed     | 297       |
# |    total_timesteps  | 212520    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 134       |
# |    n_updates        | 40629     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 312       |
# |    fps              | 709       |
# |    time_elapsed     | 303       |
# |    total_timesteps  | 215280    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 112       |
# |    n_updates        | 41319     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 316       |
# |    fps              | 703       |
# |    time_elapsed     | 309       |
# |    total_timesteps  | 218040    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 112       |
# |    n_updates        | 42009     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 320       |
# |    fps              | 698       |
# |    time_elapsed     | 316       |
# |    total_timesteps  | 220800    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 85.2      |
# |    n_updates        | 42699     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 324       |
# |    fps              | 693       |
# |    time_elapsed     | 322       |
# |    total_timesteps  | 223560    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 90.3      |
# |    n_updates        | 43389     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 328       |
# |    fps              | 689       |
# |    time_elapsed     | 328       |
# |    total_timesteps  | 226320    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 88.7      |
# |    n_updates        | 44079     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 332       |
# |    fps              | 685       |
# |    time_elapsed     | 334       |
# |    total_timesteps  | 229080    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 101       |
# |    n_updates        | 44769     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 336       |
# |    fps              | 681       |
# |    time_elapsed     | 340       |
# |    total_timesteps  | 231840    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 117       |
# |    n_updates        | 45459     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 340       |
# |    fps              | 678       |
# |    time_elapsed     | 345       |
# |    total_timesteps  | 234600    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 80.1      |
# |    n_updates        | 46149     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 344       |
# |    fps              | 673       |
# |    time_elapsed     | 352       |
# |    total_timesteps  | 237360    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 99.1      |
# |    n_updates        | 46839     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 348       |
# |    fps              | 670       |
# |    time_elapsed     | 358       |
# |    total_timesteps  | 240120    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 67.5      |
# |    n_updates        | 47529     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 352       |
# |    fps              | 667       |
# |    time_elapsed     | 364       |
# |    total_timesteps  | 242880    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 105       |
# |    n_updates        | 48219     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 356       |
# |    fps              | 663       |
# |    time_elapsed     | 370       |
# |    total_timesteps  | 245640    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 67.5      |
# |    n_updates        | 48909     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 360       |
# |    fps              | 661       |
# |    time_elapsed     | 375       |
# |    total_timesteps  | 248400    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 94.2      |
# |    n_updates        | 49599     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 364       |
# |    fps              | 660       |
# |    time_elapsed     | 380       |
# |    total_timesteps  | 251160    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 110       |
# |    n_updates        | 50289     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 368       |
# |    fps              | 658       |
# |    time_elapsed     | 385       |
# |    total_timesteps  | 253920    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 67.4      |
# |    n_updates        | 50979     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 372       |
# |    fps              | 656       |
# |    time_elapsed     | 390       |
# |    total_timesteps  | 256680    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 91.9      |
# |    n_updates        | 51669     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 376       |
# |    fps              | 654       |
# |    time_elapsed     | 396       |
# |    total_timesteps  | 259440    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# ...
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1332      |
# |    fps              | 660       |
# |    time_elapsed     | 1392      |
# |    total_timesteps  | 919080    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 69        |
# |    n_updates        | 217269    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1336      |
# |    fps              | 660       |
# |    time_elapsed     | 1396      |
# |    total_timesteps  | 921840    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 67.4      |
# |    n_updates        | 217959    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1340      |
# |    fps              | 659       |
# |    time_elapsed     | 1401      |
# |    total_timesteps  | 924600    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 38.5      |
# |    n_updates        | 218649    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1344      |
# |    fps              | 660       |
# |    time_elapsed     | 1405      |
# |    total_timesteps  | 927360    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 40.3      |
# |    n_updates        | 219339    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.02e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1348      |
# |    fps              | 660       |
# |    time_elapsed     | 1408      |
# |    total_timesteps  | 930120    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 43.3      |
# |    n_updates        | 220029    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.01e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1352      |
# |    fps              | 660       |
# |    time_elapsed     | 1413      |
# |    total_timesteps  | 932880    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 48.9      |
# |    n_updates        | 220719    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -9.95e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1356      |
# |    fps              | 660       |
# |    time_elapsed     | 1417      |
# |    total_timesteps  | 935640    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 37.7      |
# |    n_updates        | 221409    |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -9.8e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 660      |
# |    time_elapsed     | 1421     |
# |    total_timesteps  | 938400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 29.8     |
# |    n_updates        | 222099   |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -9.63e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1364      |
# |    fps              | 660       |
# |    time_elapsed     | 1425      |
# |    total_timesteps  | 941160    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 30.4      |
# |    n_updates        | 222789    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -9.42e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1368      |
# |    fps              | 660       |
# |    time_elapsed     | 1429      |
# |    total_timesteps  | 943920    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 25.2      |
# |    n_updates        | 223479    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -9.27e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1372      |
# |    fps              | 660       |
# |    time_elapsed     | 1433      |
# |    total_timesteps  | 946680    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36        |
# |    n_updates        | 224169    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -9.07e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1376      |
# |    fps              | 660       |
# |    time_elapsed     | 1437      |
# |    total_timesteps  | 949440    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 38.9      |
# |    n_updates        | 224859    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -8.92e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1380      |
# |    fps              | 660       |
# |    time_elapsed     | 1441      |
# |    total_timesteps  | 952200    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 33.3      |
# |    n_updates        | 225549    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -8.73e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1384      |
# |    fps              | 660       |
# |    time_elapsed     | 1446      |
# |    total_timesteps  | 954960    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36.6      |
# |    n_updates        | 226239    |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -8.6e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 660      |
# |    time_elapsed     | 1450     |
# |    total_timesteps  | 957720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.6     |
# |    n_updates        | 226929   |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -8.37e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1392      |
# |    fps              | 660       |
# |    time_elapsed     | 1454      |
# |    total_timesteps  | 960480    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 52        |
# |    n_updates        | 227619    |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -8.2e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 660      |
# |    time_elapsed     | 1458     |
# |    total_timesteps  | 963240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.3     |
# |    n_updates        | 228309   |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -8.07e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1400      |
# |    fps              | 660       |
# |    time_elapsed     | 1462      |
# |    total_timesteps  | 966000    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 30.7      |
# |    n_updates        | 228999    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -7.93e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1404      |
# |    fps              | 660       |
# |    time_elapsed     | 1466      |
# |    total_timesteps  | 968760    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 23        |
# |    n_updates        | 229689    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -7.71e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1408      |
# |    fps              | 660       |
# |    time_elapsed     | 1470      |
# |    total_timesteps  | 971520    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 48.6      |
# |    n_updates        | 230379    |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -7.5e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 660      |
# |    time_elapsed     | 1475     |
# |    total_timesteps  | 974280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.1     |
# |    n_updates        | 231069   |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -7.27e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1416      |
# |    fps              | 660       |
# |    time_elapsed     | 1479      |
# |    total_timesteps  | 977040    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 41.2      |
# |    n_updates        | 231759    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -7.05e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1420      |
# |    fps              | 660       |
# |    time_elapsed     | 1483      |
# |    total_timesteps  | 979800    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 39.9      |
# |    n_updates        | 232449    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -6.78e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1424      |
# |    fps              | 660       |
# |    time_elapsed     | 1487      |
# |    total_timesteps  | 982560    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 45.1      |
# |    n_updates        | 233139    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -6.55e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1428      |
# |    fps              | 660       |
# |    time_elapsed     | 1491      |
# |    total_timesteps  | 985320    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 36        |
# |    n_updates        | 233829    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -6.33e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1432      |
# |    fps              | 660       |
# |    time_elapsed     | 1495      |
# |    total_timesteps  | 988080    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 38.4      |
# |    n_updates        | 234519    |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -6.1e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 660      |
# |    time_elapsed     | 1499     |
# |    total_timesteps  | 990840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 60.2     |
# |    n_updates        | 235209   |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -5.95e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1440      |
# |    fps              | 660       |
# |    time_elapsed     | 1503      |
# |    total_timesteps  | 993600    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 40.2      |
# |    n_updates        | 235899    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -5.76e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1444      |
# |    fps              | 660       |
# |    time_elapsed     | 1508      |
# |    total_timesteps  | 996360    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 38.9      |
# |    n_updates        | 236589    |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -5.6e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 660      |
# |    time_elapsed     | 1512     |
# |    total_timesteps  | 999120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 44.5     |
# |    n_updates        | 237279   |
# ----------------------------------

# %% [markdown]
# DQN
#
# ![image.png](attachment:c93c86bb-5b87-4583-b00b-2d8b29d1dc34.png)
#
# Average reward after 1,000,000 timesteps = -5605

# %% [markdown]
# ## A2C

# %%
model3 = A2C('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model3.learn(total_timesteps = 1000000)
# Out:
# Logging to Training\logs\A2C_3
# ------------------------------------
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.0263  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 20099    |
# |    policy_loss        | 0.124    |
# |    value_loss         | 1.44e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.75e+04 |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 200       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.0523   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20199     |
# |    policy_loss        | 0.283     |
# |    value_loss         | 1.44e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 300       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -0.0575   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20299     |
# |    policy_loss        | -1.45     |
# |    value_loss         | 2.68e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 223       |
# |    iterations         | 400       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -0.0496   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20399     |
# |    policy_loss        | -1.39     |
# |    value_loss         | 5.24e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 500       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.0379   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20499     |
# |    policy_loss        | 0.191     |
# |    value_loss         | 1.45e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 239       |
# |    iterations         | 600       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.0286   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20599     |
# |    policy_loss        | 0.0496    |
# |    value_loss         | 1.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 244       |
# |    iterations         | 700       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.0272   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20699     |
# |    policy_loss        | -0.274    |
# |    value_loss         | 5.68e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 800       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.0192   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20799     |
# |    policy_loss        | -0.184    |
# |    value_loss         | 5.68e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 242       |
# |    iterations         | 900       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.00946  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20899     |
# |    policy_loss        | -0.0344   |
# |    value_loss         | 2.57e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 244       |
# |    iterations         | 1000      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.00992  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 20999     |
# |    policy_loss        | -0.139    |
# |    value_loss         | 2.29e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 241       |
# |    iterations         | 1100      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.0111   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21099     |
# |    policy_loss        | -0.0418   |
# |    value_loss         | 6.42e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 242       |
# |    iterations         | 1200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.0176   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21199     |
# |    policy_loss        | -0.659    |
# |    value_loss         | 1.03e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 1300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.0346   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21299     |
# |    policy_loss        | 0.172     |
# |    value_loss         | 1.46e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 1400      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.0449   |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21399     |
# |    policy_loss        | -0.652    |
# |    value_loss         | 2.17e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 1500      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.0261   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21499     |
# |    policy_loss        | -0.111    |
# |    value_loss         | 6.41e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 253       |
# |    iterations         | 1600      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.0171   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21599     |
# |    policy_loss        | 0.0759    |
# |    value_loss         | 1.47e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 1700      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.0105   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21699     |
# |    policy_loss        | 0.016     |
# |    value_loss         | 1.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 1800      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.00873  |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21799     |
# |    policy_loss        | -0.188    |
# |    value_loss         | 5.23e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 1900      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.00904  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21899     |
# |    policy_loss        | -0.0793   |
# |    value_loss         | 1.23e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 2000      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.00558  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 21999     |
# |    policy_loss        | -0.0982   |
# |    value_loss         | 2.66e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 2100      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.00577  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22099     |
# |    policy_loss        | 0.0223    |
# |    value_loss         | 1.48e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 2200      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.00397  |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22199     |
# |    policy_loss        | -0.113    |
# |    value_loss         | 8.41e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 2300      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.00418  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22299     |
# |    policy_loss        | -0.043    |
# |    value_loss         | 2.17e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 2400      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.00452  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22399     |
# |    policy_loss        | 0.0171    |
# |    value_loss         | 1.48e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 2500      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.00256  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22499     |
# |    policy_loss        | 0.00896   |
# |    value_loss         | 1.48e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 2600      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.00259  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22599     |
# |    policy_loss        | -0.0417   |
# |    value_loss         | 2.66e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 2700      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.00272  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22699     |
# |    policy_loss        | -0.0618   |
# |    value_loss         | 5.57e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 2800      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.00288  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22799     |
# |    policy_loss        | 0.0102    |
# |    value_loss         | 1.49e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 2900      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.00328  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22899     |
# |    policy_loss        | 0.0044    |
# |    value_loss         | 1.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 3000      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00392  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 22999     |
# |    policy_loss        | 0.00539   |
# |    value_loss         | 1.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 3100      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.00569  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23099     |
# |    policy_loss        | -0.101    |
# |    value_loss         | 3.8e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 3200      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.0111   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23199     |
# |    policy_loss        | 0.0481    |
# |    value_loss         | 1.5e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 262       |
# |    iterations         | 3300      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.0428   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23299     |
# |    policy_loss        | -0.205    |
# |    value_loss         | 6.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 3400      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.0307   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23399     |
# |    policy_loss        | 0.0588    |
# |    value_loss         | 1.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 3500      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.0625   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23499     |
# |    policy_loss        | -2.4      |
# |    value_loss         | 5.56e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 3600      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.0694   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23599     |
# |    policy_loss        | 0.435     |
# |    value_loss         | 1.5e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 3700      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.0409   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23699     |
# |    policy_loss        | -0.476    |
# |    value_loss         | 1.22e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 3800      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.12     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23799     |
# |    policy_loss        | 16.8      |
# |    value_loss         | 6.35e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 262       |
# |    iterations         | 3900      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.156    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23899     |
# |    policy_loss        | -5.65     |
# |    value_loss         | 2.65e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 262       |
# |    iterations         | 4000      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.0279   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23999     |
# |    policy_loss        | 0.144     |
# |    value_loss         | 1.51e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 4100      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.0231   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24099     |
# |    policy_loss        | -0.38     |
# |    value_loss         | 1.89e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 4200      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.0219   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24199     |
# |    policy_loss        | -0.0925   |
# |    value_loss         | 6.34e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 4300      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.025    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24299     |
# |    policy_loss        | 0.124     |
# |    value_loss         | 1.52e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 262       |
# |    iterations         | 4400      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.0184   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24399     |
# |    policy_loss        | 0.0854    |
# |    value_loss         | 1.52e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 4500      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.0479   |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24499     |
# |    policy_loss        | -1.65     |
# |    value_loss         | 5.55e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 4600      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.0694   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24599     |
# |    policy_loss        | -2.11     |
# |    value_loss         | 5.2e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 4700      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.0372   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24699     |
# |    policy_loss        | -0.392    |
# |    value_loss         | 5.57e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 4800      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.0297   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24799     |
# |    policy_loss        | 0.147     |
# |    value_loss         | 1.53e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 4900      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.0228   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24899     |
# |    policy_loss        | -0.487    |
# |    value_loss         | 2.64e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 5000      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.021    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24999     |
# |    policy_loss        | -0.267    |
# |    value_loss         | 2.15e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 5100      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.0248   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25099     |
# |    policy_loss        | 0.12      |
# |    value_loss         | 1.53e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 5200      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.0242   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25199     |
# |    policy_loss        | 0.0442    |
# |    value_loss         | 1.37e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 5300      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.0374   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25299     |
# |    policy_loss        | -0.392    |
# |    value_loss         | 5.55e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 262       |
# |    iterations         | 5400      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.0342   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25399     |
# |    policy_loss        | -1.31     |
# |    value_loss         | 8.37e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 5500      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -0.0271   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25499     |
# |    policy_loss        | 0.133     |
# |    value_loss         | 1.54e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 5600      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.0302   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25599     |
# |    policy_loss        | -0.495    |
# |    value_loss         | 2.26e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 5700      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.034    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25699     |
# |    policy_loss        | 0.0662    |
# |    value_loss         | 1.37e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 5800      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.0454   |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25799     |
# |    policy_loss        | -1.83     |
# |    value_loss         | 8.36e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 5900      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.0376   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25899     |
# |    policy_loss        | 0.195     |
# |    value_loss         | 1.55e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6000      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -0.0291   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25999     |
# |    policy_loss        | -0.387    |
# |    value_loss         | 2.14e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6100      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -0.0236   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26099     |
# |    policy_loss        | 0.114     |
# |    value_loss         | 1.55e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 6200      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.0156   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26199     |
# |    policy_loss        | -0.443    |
# |    value_loss         | 5.53e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 6300      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.0105   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26299     |
# |    policy_loss        | 0.0452    |
# |    value_loss         | 1.56e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 6400      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.00677  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26399     |
# |    policy_loss        | -0.122    |
# |    value_loss         | 3.77e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 253       |
# |    iterations         | 6500      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.00724  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26499     |
# |    policy_loss        | 0.0114    |
# |    value_loss         | 1.37e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 6600      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.00755  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26599     |
# |    policy_loss        | -0.0623   |
# |    value_loss         | 5.52e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 6700      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.00974  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26699     |
# |    policy_loss        | 0.016     |
# |    value_loss         | 1.37e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 6800      |
# |    time_elapsed       | 136       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.0126   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26799     |
# |    policy_loss        | -0.347    |
# |    value_loss         | 5.52e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 6900      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -0.00792  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26899     |
# |    policy_loss        | -0.264    |
# |    value_loss         | 1.02e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 7000      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.0104   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26999     |
# |    policy_loss        | 0.0446    |
# |    value_loss         | 1.57e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 7100      |
# |    time_elapsed       | 143       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.0214   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27099     |
# |    policy_loss        | 0.104     |
# |    value_loss         | 1.57e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 7200      |
# |    time_elapsed       | 146       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.00714  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27199     |
# |    policy_loss        | -0.129    |
# |    value_loss         | 2.63e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 7300      |
# |    time_elapsed       | 148       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -0.0081   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27299     |
# |    policy_loss        | -0.17     |
# |    value_loss         | 5.17e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 243       |
# |    iterations         | 7400      |
# |    time_elapsed       | 152       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.00482  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27399     |
# |    policy_loss        | 0.0188    |
# |    value_loss         | 1.58e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 241       |
# |    iterations         | 7500      |
# ...
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 24000     |
# |    time_elapsed       | 532       |
# |    total_timesteps    | 120000    |
# | train/                |           |
# |    entropy_loss       | -0.0202   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 43999     |
# |    policy_loss        | -0.0726   |
# |    value_loss         | 5.85e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 24100     |
# |    time_elapsed       | 534       |
# |    total_timesteps    | 120500    |
# | train/                |           |
# |    entropy_loss       | -0.0283   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44099     |
# |    policy_loss        | 0.072     |
# |    value_loss         | 1.45e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 24200     |
# |    time_elapsed       | 536       |
# |    total_timesteps    | 121000    |
# | train/                |           |
# |    entropy_loss       | -0.0273   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44199     |
# |    policy_loss        | -0.873    |
# |    value_loss         | 5.33e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 24300     |
# |    time_elapsed       | 538       |
# |    total_timesteps    | 121500    |
# | train/                |           |
# |    entropy_loss       | -0.0559   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44299     |
# |    policy_loss        | 0.373     |
# |    value_loss         | 1.92e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 24400     |
# |    time_elapsed       | 540       |
# |    total_timesteps    | 122000    |
# | train/                |           |
# |    entropy_loss       | -0.0364   |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44399     |
# |    policy_loss        | -0.386    |
# |    value_loss         | 1.12e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 24500     |
# |    time_elapsed       | 542       |
# |    total_timesteps    | 122500    |
# | train/                |           |
# |    entropy_loss       | -0.0268   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44499     |
# |    policy_loss        | -0.0991   |
# |    value_loss         | 5.84e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 24600     |
# |    time_elapsed       | 544       |
# |    total_timesteps    | 123000    |
# | train/                |           |
# |    entropy_loss       | -0.0174   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44599     |
# |    policy_loss        | -0.35     |
# |    value_loss         | 2.5e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 24700     |
# |    time_elapsed       | 546       |
# |    total_timesteps    | 123500    |
# | train/                |           |
# |    entropy_loss       | -0.0162   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44699     |
# |    policy_loss        | 0.0817    |
# |    value_loss         | 1.93e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 24800     |
# |    time_elapsed       | 548       |
# |    total_timesteps    | 124000    |
# | train/                |           |
# |    entropy_loss       | -0.0183   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44799     |
# |    policy_loss        | -0.266    |
# |    value_loss         | 1.76e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 24900     |
# |    time_elapsed       | 550       |
# |    total_timesteps    | 124500    |
# | train/                |           |
# |    entropy_loss       | -0.0245   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44899     |
# |    policy_loss        | -0.0865   |
# |    value_loss         | 5.83e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 25000     |
# |    time_elapsed       | 551       |
# |    total_timesteps    | 125000    |
# | train/                |           |
# |    entropy_loss       | -0.0344   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 44999     |
# |    policy_loss        | 0.199     |
# |    value_loss         | 1.93e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 25100     |
# |    time_elapsed       | 553       |
# |    total_timesteps    | 125500    |
# | train/                |           |
# |    entropy_loss       | -0.0157   |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45099     |
# |    policy_loss        | 0.0802    |
# |    value_loss         | 1.94e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 25200     |
# |    time_elapsed       | 555       |
# |    total_timesteps    | 126000    |
# | train/                |           |
# |    entropy_loss       | -0.0166   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45199     |
# |    policy_loss        | -0.47     |
# |    value_loss         | 5.32e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 25300     |
# |    time_elapsed       | 557       |
# |    total_timesteps    | 126500    |
# | train/                |           |
# |    entropy_loss       | -0.0177   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45299     |
# |    policy_loss        | -0.408    |
# |    value_loss         | 4.98e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 25400     |
# |    time_elapsed       | 559       |
# |    total_timesteps    | 127000    |
# | train/                |           |
# |    entropy_loss       | -0.00839  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45399     |
# |    policy_loss        | -0.0681   |
# |    value_loss         | 5.01e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 25500     |
# |    time_elapsed       | 561       |
# |    total_timesteps    | 127500    |
# | train/                |           |
# |    entropy_loss       | -0.00872  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45499     |
# |    policy_loss        | 0.0419    |
# |    value_loss         | 1.94e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 25600     |
# |    time_elapsed       | 563       |
# |    total_timesteps    | 128000    |
# | train/                |           |
# |    entropy_loss       | -0.00444  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45599     |
# |    policy_loss        | -0.0746   |
# |    value_loss         | 2.5e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 25700     |
# |    time_elapsed       | 565       |
# |    total_timesteps    | 128500    |
# | train/                |           |
# |    entropy_loss       | -0.00453  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45699     |
# |    policy_loss        | -0.045    |
# |    value_loss         | 2.02e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 25800     |
# |    time_elapsed       | 566       |
# |    total_timesteps    | 129000    |
# | train/                |           |
# |    entropy_loss       | -0.00482  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45799     |
# |    policy_loss        | 0.0211    |
# |    value_loss         | 1.95e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 25900     |
# |    time_elapsed       | 568       |
# |    total_timesteps    | 129500    |
# | train/                |           |
# |    entropy_loss       | -0.00263  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45899     |
# |    policy_loss        | 0.00482   |
# |    value_loss         | 1.45e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 26000     |
# |    time_elapsed       | 570       |
# |    total_timesteps    | 130000    |
# | train/                |           |
# |    entropy_loss       | -0.00269  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 45999     |
# |    policy_loss        | -0.0185   |
# |    value_loss         | 5e+03     |
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 model3.learn(total_timesteps = 1000000)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\a2c\a2c.py:190, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     181 def learn(
#     182     self: SelfA2C,
#     183     total_timesteps: int,
#    (...)
#     188     progress_bar: bool = False,
#     189 ) -> SelfA2C:
# --> 190     return super().learn(
#     191         total_timesteps=total_timesteps,
#     192         callback=callback,
#     193         log_interval=log_interval,
#     194         tb_log_name=tb_log_name,
#     195         reset_num_timesteps=reset_num_timesteps,
#     196         progress_bar=progress_bar,
#     197     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:246, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     243 callback.on_training_start(locals(), globals())
#     245 while self.num_timesteps < total_timesteps:
# --> 246     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     248     if continue_training is False:
#     249         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:209, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     205     self._last_episode_starts = dones
#     207 with th.no_grad():
#     208     # Compute value for the last timestep
# --> 209     values = self.policy.predict_values(obs_as_tensor(new_obs, self.device))
#     211 rollout_buffer.compute_returns_and_advantage(last_values=values, dones=dones)
#     213 callback.on_rollout_end()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\utils.py:485, in obs_as_tensor(obs, device)
#     477 """
#     478 Moves the observation to the given device.
#     479
#    (...)
#     482 :return: PyTorch tensor of the observation on a desired device.
#     483 """
#     484 if isinstance(obs, np.ndarray):
# --> 485     return th.as_tensor(obs, device=device)
#     486 elif isinstance(obs, dict):
#     487     return {key: th.as_tensor(_obs, device=device) for (key, _obs) in obs.items()}
#
# KeyboardInterrupt:

# %% [markdown]
# A2C
#
# Average reward after 130000 timesteps = -17700
#
# ![Pasted image 20231110214713.png](attachment:6cdb0c86-e9c2-4c7c-bcb1-f0cc9c923062.png)
#
# The average episode reward stays the same even after further training and has minimal change

# %% [markdown]
# ## Comparison

# %% [markdown]
# ![image.png](attachment:d0553499-4aa1-47d2-994f-31d94d9bc0c2.png)
#
# DQN - Pink
# PPO - Green
# A2C - Blue
#
# The DQN model was able to better fit on the data while A2C and PPO reached stagnation

# %% [markdown]
# # Environment - 2

# %% [markdown]
# Modifying the state space and reducing the variables to achieve convergence faster as the previous models may have been slow in converging due to a complex state space. The average rewards achieved by the models did not show much improvement over the reward gained using random actions.
# ### State
#
# The data was modeled to function like an environment where the state space of the agent would be an array consisting of
# - Energy consumption of previous hour
# - Value of the previous hour
#
# ### Action
# Using the given state space, in this environment the agent would be required to predict the fall, rise or constant energy requirement for the next day, giving the agent 3 possible actions - Increase, Decrease and Constant.
#
# ### Reward
# For a correct prediction of the change in power consumption, the agent would be given a reward of +10 whereas a wrong prediction would give the agent a reward of -100.
#
# In cases where the agent chose the action as constant, if the power consumption of next day is within 5%, then the agent is given a positive reward else it is given a negative reward. This condition is represented as follows
#
# $0.95 * Energy_t <= Energy_{t+1}<= 1.05 * Energy_t$
#
# where $t$ is timestep t.

# %%
class PowerPredEnv2(Env):
    def __init__(self):
        self.action_space = Discrete(3) # Increase, Decrease, keep same
        self.observation_space = Box(low=np.array([0,0]), high=np.array([23,63000]), dtype=np.int32) ## [Hour of day, Power in MW]
        self.day = 0 #Current day - Opens the day's CSV file
        self.hour = 0 # Hour - Row number of the CSV
        self.state = [self.hour, pd_refs[self.day].loc[self.hour,"MW"]] ## State of the environment

    def get_current_power(self):
        ## Returns the power consumption of the day stored in self.day
        return pd_refs[self.day].loc[self.hour,"MW"]

    def next_day(self):
        ## Changes the day to next day and checks if all CSV files have been read
        self.day += 1
        if(self.day == 30):
            return True
        self.hour = 0
        self.state = [self.hour, self.get_current_power()]
        return False
        
    def step(self, action):
        actual_power = pd_refs[self.day].loc[self.hour+1,"MW"] # Actual power at hour t+1
        prev_power = self.state[1] # Power of previous day
        done = False
        reward = 0
        ## 0 - Increase, 1 - Decrease, 2 - Same
        if(action == 0):
            if(actual_power > prev_power):
                 ## Correct prediction of increase in power demand
                reward = 10
            else:
                reward = -100
        elif(action == 1):
            if(actual_power < prev_power):
                 ## Correct prediction of decrease in power demand
                reward = 10
            else:
                reward = -100
        elif(action == 2):
             ## Correct prediction of constant power demand
             ## The power is within 5% of the previous day's power consumption
            if(0.95*prev_power < actual_power < 1.05 * prev_power):
                reward = 10
            else:
                reward = -100
        self.hour +=1
        done = False
        if(self.hour == 23):
            ## If all hours of the day are completed, move to next file
            done = self.next_day()
        if not done:
            ## Check if all files are read, if not continue 
            self.state = [self.hour, self.get_current_power()]
        info = {
            "day":self.day+1,
            "reward":reward,
            "hour":self.hour-1,
            "prev":prev_power,
            "predicted":action,
            "actual":actual_power
        }
        return self.state, reward, False, done, info
    
    def render(self):
        pass
    
    def reset(self):
        ## Reset the values
        self.day = 0
        self.hour = 0
        self.state = [self.hour, self.get_current_power()]
        info = {
                    "day":self.day+1,
                    "reward":reward,
                    "hour":self.hour-1,
                    "predicted":action,
                }
        return self.state, info

# %%
env = PowerPredEnv2()

# %% [markdown]
# ## Result using random action selection for 5 episodes

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, _, done, info = env.step(action)
        score += reward
        # if(reward > 0):
        #     print(reward, info)
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-24120
# Episode:2 Score:-27420
# Episode:3 Score:-28190
# Episode:4 Score:-25440
# Episode:5 Score:-28080

# %% [markdown]
# ## PPO

# %%
log_path = os.path.join('Training', 'logs')
model1 = PPO('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model1.learn(total_timesteps=1000000)
# Out:
# Logging to Training\logs\PPO_9
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 690       |
# |    ep_rew_mean     | -1.78e+04 |
# | time/              |           |
# |    fps             | 441       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 363           |
# |    iterations           | 2             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00010378775 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.02         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.54e+04      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000222     |
# |    value_loss           | 1.6e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 346           |
# |    iterations           | 3             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 6.4300257e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0184       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.22e+04      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -2.16e-05     |
# |    value_loss           | 1.57e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 335           |
# |    iterations           | 4             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 2.5976857e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0176       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.76e+04      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000105     |
# |    value_loss           | 1.57e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 5            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 4.741014e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0165      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.49e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 8.38e-08     |
# |    value_loss           | 1.53e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 322           |
# |    iterations           | 6             |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 2.9691291e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0177       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.92e+04      |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -8.86e-05     |
# |    value_loss           | 1.51e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 7            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 2.066372e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.019       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.32e+04     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 3.46e-07     |
# |    value_loss           | 1.52e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 8            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 8.564326e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0183      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.62e+04     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -3.19e-05    |
# |    value_loss           | 1.54e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 9            |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 3.958121e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0177      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.62e+04     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -1.22e-06    |
# |    value_loss           | 1.53e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 10           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 6.194372e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0172      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7e+04        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -4.42e-05    |
# |    value_loss           | 1.53e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 316           |
# |    iterations           | 11            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 5.2502146e-05 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0151       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.35e+04      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000242     |
# |    value_loss           | 1.53e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 316           |
# |    iterations           | 12            |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 3.4864643e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0138       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.32e+04      |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -1.76e-05     |
# |    value_loss           | 1.5e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 13            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.7236162e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0131       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.5e+04       |
# |    n_updates            | 610           |
# |    policy_gradient_loss | -1.25e-05     |
# |    value_loss           | 1.5e+05       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 14           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 5.016627e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0126      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.47e+04     |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -8.01e-06    |
# |    value_loss           | 1.47e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 15            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 4.7139474e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.012        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.01e+04      |
# |    n_updates            | 630           |
# |    policy_gradient_loss | -3.65e-05     |
# |    value_loss           | 1.48e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 16            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.3113604e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0118       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.67e+04      |
# |    n_updates            | 640           |
# |    policy_gradient_loss | -4.66e-06     |
# |    value_loss           | 1.45e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 17           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 4.951522e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0117      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.38e+04     |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -1.57e-05    |
# |    value_loss           | 1.45e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 18            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 4.1943567e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.011        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.06e+04      |
# |    n_updates            | 660           |
# |    policy_gradient_loss | -3.41e-05     |
# |    value_loss           | 1.44e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 19           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 4.665344e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0104      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.2e+04      |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -6.91e-06    |
# |    value_loss           | 1.42e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 314           |
# |    iterations           | 20            |
# |    time_elapsed         | 130           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.3587705e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0105       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.73e+04      |
# |    n_updates            | 680           |
# |    policy_gradient_loss | -1.9e-05      |
# |    value_loss           | 1.42e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 21           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 6.406917e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0108      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.65e+04     |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -4.19e-06    |
# |    value_loss           | 1.41e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 22           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 3.963796e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0111      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.68e+04     |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -4.71e-05    |
# |    value_loss           | 1.38e+05     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 23        |
# |    time_elapsed         | 149       |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0112   |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.16e+04  |
# |    n_updates            | 710       |
# |    policy_gradient_loss | 4.99e-09  |
# |    value_loss           | 1.39e+05  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 24           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 4.656613e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0113      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.07e+04     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | 5.85e-08     |
# |    value_loss           | 1.38e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 25           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 9.670737e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0118      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.08e+04     |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -5.59e-05    |
# |    value_loss           | 1.4e+05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 312           |
# |    iterations           | 26            |
# |    time_elapsed         | 170           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 1.4819088e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0123       |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.59e+04      |
# |    n_updates            | 740           |
# |    policy_gradient_loss | -7.19e-06     |
# |    value_loss           | 1.41e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 27           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 8.805655e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.012       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7e+04        |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -6.16e-06    |
# |    value_loss           | 1.41e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.77e+04   |
# | time/                   |             |
# |    fps                  | 310         |
# |    iterations           | 28          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 3.17159e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0122     |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.87e+04    |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -2.93e-05   |
# |    value_loss           | 1.4e+05     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 310           |
# |    iterations           | 29            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.4719466e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0128       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.11e+04      |
# |    n_updates            | 770           |
# |    policy_gradient_loss | -9.65e-05     |
# |    value_loss           | 1.38e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 310           |
# |    iterations           | 30            |
# |    time_elapsed         | 197           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 2.0070001e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0131       |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.23e+04      |
# |    n_updates            | 780           |
# |    policy_gradient_loss | -2.39e-06     |
# |    value_loss           | 1.36e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 31            |
# |    time_elapsed         | 204           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 2.9217626e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0132       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.71e+04      |
# |    n_updates            | 790           |
# |    policy_gradient_loss | -2.47e-05     |
# |    value_loss           | 1.35e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.77e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 32            |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 4.6018686e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0133       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.86e+04      |
# |    n_updates            | 800           |
# |    policy_gradient_loss | -4.99e-05     |
# |    value_loss           | 1.36e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.77e+04    |
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 33           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 8.702045e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0133      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.18e+04     |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 1.9e-06      |
# |    value_loss           | 1.34e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.77e+04   |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 34          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 8.92143e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0127     |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.29e+04    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -5.81e-05   |
# |    value_loss           | 1.34e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 35            |
# |    time_elapsed         | 230           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.2450619e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.012        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.44e+04      |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -1.1e-06      |
# |    value_loss           | 1.33e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 36            |
# |    time_elapsed         | 236           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 1.0333315e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0118       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.74e+04      |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -2.02e-05     |
# |    value_loss           | 1.31e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 37            |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 3.2427488e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0116       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.73e+04      |
# |    n_updates            | 850           |
# |    policy_gradient_loss | -1.09e-06     |
# |    value_loss           | 1.29e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 38            |
# |    time_elapsed         | 249           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 2.5301706e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0114       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.78e+04      |
# |    n_updates            | 860           |
# |    policy_gradient_loss | -2.65e-05     |
# |    value_loss           | 1.3e+05       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.76e+04    |
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 39           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 5.365914e-05 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0102      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.92e+04     |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000199    |
# |    value_loss           | 1.32e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 40            |
# |    time_elapsed         | 262           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 2.5088666e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00966      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.1e+04       |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -1.09e-05     |
# |    value_loss           | 1.32e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 41            |
# |    time_elapsed         | 269           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 1.9366707e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00936      |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.95e+04      |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -0.000105     |
# |    value_loss           | 1.32e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.76e+04    |
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 42           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 2.640998e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00875     |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.12e+04     |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -4.76e-05    |
# |    value_loss           | 1.3e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.76e+04    |
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 43           |
# |    time_elapsed         | 282          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 2.810033e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00867     |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.8e+04      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -1.36e-05    |
# |    value_loss           | 1.29e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 44            |
# |    time_elapsed         | 289           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 5.9604645e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00853      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.21e+04      |
# |    n_updates            | 920           |
# |    policy_gradient_loss | -5.54e-09     |
# |    value_loss           | 1.28e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.76e+04    |
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 45           |
# |    time_elapsed         | 295          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 3.011839e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00833     |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.76e+04     |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -8.85e-06    |
# |    value_loss           | 1.28e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 46            |
# |    time_elapsed         | 302           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 3.7604186e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00846      |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.05e+04      |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -3.2e-05      |
# |    value_loss           | 1.26e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 311           |
# |    iterations           | 47            |
# |    time_elapsed         | 308           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 5.0349627e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0088       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.8e+04       |
# |    n_updates            | 950           |
# |    policy_gradient_loss | 1.82e-06      |
# |    value_loss           | 1.25e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 312           |
# |    iterations           | 48            |
# |    time_elapsed         | 314           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 4.4219487e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00849      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.32e+04      |
# |    n_updates            | 960           |
# |    policy_gradient_loss | -4.07e-05     |
# |    value_loss           | 1.25e+05      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.76e+04 |
# | time/                   |           |
# |    fps                  | 312       |
# |    iterations           | 49        |
# |    time_elapsed         | 321       |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0081   |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.28e+04  |
# |    n_updates            | 970       |
# |    policy_gradient_loss | 1.29e-09  |
# |    value_loss           | 1.22e+05  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 312           |
# |    iterations           | 50            |
# |    time_elapsed         | 327           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 4.5578927e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00775      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.05e+04      |
# |    n_updates            | 980           |
# |    policy_gradient_loss | -6.44e-05     |
# |    value_loss           | 1.23e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.76e+04   |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 51          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 2.12749e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00737    |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.83e+04    |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -2.24e-07   |
# |    value_loss           | 1.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.76e+04   |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 52          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 5.65371e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00744    |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.6e+04     |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -2.85e-06   |
# |    value_loss           | 1.2e+05     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 312           |
# |    iterations           | 53            |
# |    time_elapsed         | 346           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 2.0849984e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00797      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.36e+04      |
# |    n_updates            | 1010          |
# |    policy_gradient_loss | -8.14e-05     |
# |    value_loss           | 1.2e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 313           |
# |    iterations           | 54            |
# |    time_elapsed         | 352           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 5.9604645e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00855      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.64e+04      |
# |    n_updates            | 1020          |
# |    policy_gradient_loss | 7.19e-10      |
# |    value_loss           | 1.19e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 313           |
# |    iterations           | 55            |
# |    time_elapsed         | 359           |
# |    total_timesteps      | 112640        |
# | train/                  |               |
# |    approx_kl            | 8.3833584e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00853      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.52e+04      |
# |    n_updates            | 1030          |
# |    policy_gradient_loss | -2.29e-05     |
# |    value_loss           | 1.17e+05      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 690            |
# |    ep_rew_mean          | -1.76e+04      |
# | time/                   |                |
# |    fps                  | 313            |
# |    iterations           | 56             |
# |    time_elapsed         | 366            |
# |    total_timesteps      | 114688         |
# | train/                  |                |
# |    approx_kl            | -5.9604645e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.00853       |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 5.97e+04       |
# |    n_updates            | 1040           |
# |    policy_gradient_loss | -1.09e-09      |
# |    value_loss           | 1.18e+05       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.76e+04     |
# | time/                   |               |
# |    fps                  | 313           |
# |    iterations           | 57            |
# |    time_elapsed         | 372           |
# |    total_timesteps      | 116736        |
# | train/                  |               |
# |    approx_kl            | 6.5435597e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00864      |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.85e+04      |
# |    n_updates            | 1050          |
# |    policy_gradient_loss | -4.3e-05      |
# |    value_loss           | 1.2e+05       |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 model1.learn(total_timesteps=1000000)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\ppo\ppo.py:304, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     295 def learn(
#     296     self: SelfPPO,
#     297     total_timesteps: int,
#    (...)
#     302     progress_bar: bool = False,
#     303 ) -> SelfPPO:
# --> 304     return super().learn(
#     305         total_timesteps=total_timesteps,
#     306         callback=callback,
#     307         log_interval=log_interval,
#     308         tb_log_name=tb_log_name,
#     309         reset_num_timesteps=reset_num_timesteps,
#     310         progress_bar=progress_bar,
#     311     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:265, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     263         self.logger.record("time/time_elapsed", int(time_elapsed), exclude="tensorboard")
#     264         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
# --> 265         self.logger.dump(step=self.num_timesteps)
#     267     self.train()
#     269 callback.on_training_end()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\logger.py:525, in Logger.dump(self, step)
#     523 for _format in self.output_formats:
#     524     if isinstance(_format, KVWriter):
# --> 525         _format.write(self.name_to_value, self.name_to_excluded, step)
#     527 self.name_to_value.clear()
#     528 self.name_to_count.clear()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\logger.py:432, in TensorBoardOutputFormat.write(self, key_values, key_excluded, step)
#     429         self.writer.file_writer.add_summary(session_end_info)
#     431 # Flush the output to the file
# --> 432 self.writer.flush()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\tensorboard\writer.py:1200, in SummaryWriter.flush(self)
#    1198     return
#    1199 for writer in self.all_writers.values():
# -> 1200     writer.flush()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\tensorboard\writer.py:150, in FileWriter.flush(self)
#     145 def flush(self):
#     146     """Flushes the event file to disk.
#     147     Call this method to make sure that all pending events have been written to
#     148     disk.
#     149     """
# --> 150     self.event_writer.flush()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorboard\summary\writer\event_file_writer.py:121, in EventFileWriter.flush(self)
#     115 def flush(self):
#     116     """Flushes the event file to disk.
#     117
#     118     Call this method to make sure that all pending events have been
#     119     written to disk.
#     120     """
# --> 121     self._async_writer.flush()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorboard\summary\writer\event_file_writer.py:177, in _AsyncWriter.flush(self)
#     175     raise IOError("Writer is closed")
#     176 self._byte_queue.join()
# --> 177 self._writer.flush()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorboard\summary\writer\record_writer.py:43, in RecordWriter.flush(self)
#      42 def flush(self):
# ---> 43     self._writer.flush()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\lib\io\file_io.py:219, in FileIO.flush(self)
#     212 """Flushes the Writable file.
#     213
#     214 This only ensures that the data has made its way out of the process without
#     215 any guarantees on whether it's written to disk. This means that the
#     216 data would survive an application crash but not necessarily an OS crash.
#     217 """
#     218 if self._writable_file:
# --> 219   self._writable_file.flush()
#
# KeyboardInterrupt:

# %% [markdown]
# PPO
#
# ![image.png](attachment:505c964d-5ac2-4a7d-a11e-73b8292fb8da.png)
#
# Average reward after 100,000 timesteps = -17900

# %% [markdown]
# ## DQN

# %%
model2 = DQN('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model2.learn(total_timesteps = 100000)
# Out:
# Logging to Training\logs\DQN_5
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.738     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 4151      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 2760      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.476     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 5444      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 5520      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.64e+04 |
# |    exploration_rate | 0.213     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 6074      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 8280      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.67e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 6648      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 11040     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 7049      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 13800     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 7371     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7603     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7803     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7928     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 24840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.7e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 8052     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 27600    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 8135      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 30360     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 8192      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 33120     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 8216      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 35880     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 8268      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 38640     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 8281      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 41400     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 8321      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 44160     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 8370      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 46920     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 8408      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 49680     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.66e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 5110      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 52440     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 58.4      |
# |    n_updates        | 609       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.63e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 3731      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 55200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 77.4      |
# |    n_updates        | 1299      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.61e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 3068      |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 57960     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 69.6      |
# |    n_updates        | 1989      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.59e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 2624      |
# |    time_elapsed     | 23        |
# |    total_timesteps  | 60720     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 58.8      |
# |    n_updates        | 2679      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.57e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 2269      |
# |    time_elapsed     | 27        |
# |    total_timesteps  | 63480     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 58        |
# |    n_updates        | 3369      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.55e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 2051      |
# |    time_elapsed     | 32        |
# |    total_timesteps  | 66240     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 78.2      |
# |    n_updates        | 4059      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.53e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 1895      |
# |    time_elapsed     | 36        |
# |    total_timesteps  | 69000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 53.7      |
# |    n_updates        | 4749      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.5e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1748     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 71760    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 58.1     |
# |    n_updates        | 5439     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.48e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 1631      |
# |    time_elapsed     | 45        |
# |    total_timesteps  | 74520     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 52        |
# |    n_updates        | 6129      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.46e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 1545      |
# |    time_elapsed     | 50        |
# |    total_timesteps  | 77280     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 56.6      |
# |    n_updates        | 6819      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.43e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 1473      |
# |    time_elapsed     | 54        |
# |    total_timesteps  | 80040     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 72.9      |
# |    n_updates        | 7509      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -2.4e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1397     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 82800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 70.7     |
# |    n_updates        | 8199     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.37e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 124       |
# |    fps              | 1340      |
# |    time_elapsed     | 63        |
# |    total_timesteps  | 85560     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 70.3      |
# |    n_updates        | 8889      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.35e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 1295      |
# |    time_elapsed     | 68        |
# |    total_timesteps  | 88320     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 61.2      |
# |    n_updates        | 9579      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.32e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 1248      |
# |    time_elapsed     | 72        |
# |    total_timesteps  | 91080     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 54.2      |
# |    n_updates        | 10269     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.29e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 136       |
# |    fps              | 1209      |
# |    time_elapsed     | 77        |
# |    total_timesteps  | 93840     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 68.7      |
# |    n_updates        | 10959     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.27e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 1178      |
# |    time_elapsed     | 81        |
# |    total_timesteps  | 96600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 65.3      |
# |    n_updates        | 11649     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.25e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 1153      |
# |    time_elapsed     | 86        |
# |    total_timesteps  | 99360     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 51.9      |
# |    n_updates        | 12339     |
# -----------------------------------

# %% [markdown]
# DQN
#
# ![image.png](attachment:dce45d2e-8cd5-4a1e-88b9-12911da93625.png)
#
# Average reward after 100,000 timesteps = -22700

# %% [markdown]
# ## A2C

# %%
model3 = A2C('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model3.learn(total_timesteps = 100000)
# Out:
# Logging to Training\logs\A2C_5
# ------------------------------------
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.754   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 9.35     |
# |    value_loss         | 1.09e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -2.32e+04 |
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 200       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.16     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 0.952     |
# |    value_loss         | 1.1e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -2.1e+04  |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 300       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -0.0807   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -257      |
# |    value_loss         | 3.78e+04  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -2.1e+04 |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.0496  |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -1.43    |
# |    value_loss         | 5.46e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -2e+04   |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.0667  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.333    |
# |    value_loss         | 1.1e+03  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.94e+04 |
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 600       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.0266   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 0.0301    |
# |    value_loss         | 1.33e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.9e+04 |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.0224  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.233   |
# |    value_loss         | 6.27e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.9e+04 |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.0183  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.187   |
# |    value_loss         | 6.27e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.88e+04 |
# | time/                 |           |
# |    fps                | 266       |
# |    iterations         | 900       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.0322   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.162    |
# |    value_loss         | 2.99e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.87e+04 |
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 1000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.0389   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.721    |
# |    value_loss         | 2.44e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.87e+04 |
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 1100      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.0093   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -0.0394   |
# |    value_loss         | 6.96e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.85e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.00954  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -0.337    |
# |    value_loss         | 1.06e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.84e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1300      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.0103   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.0378    |
# |    value_loss         | 1.12e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.83e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1400      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.0112   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.138    |
# |    value_loss         | 2.3e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.83e+04 |
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 1500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.0127   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.0559   |
# |    value_loss         | 6.95e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.83e+04 |
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 1600      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.00914  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.0327    |
# |    value_loss         | 1.12e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.82e+04 |
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1700      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.0107   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.0108    |
# |    value_loss         | 1.33e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.82e+04 |
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 1800      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.00738  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -0.158    |
# |    value_loss         | 5.45e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.82e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 1900      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.00889  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -0.082    |
# |    value_loss         | 1.33e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.81e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 2000      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.00857  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.168    |
# |    value_loss         | 2.81e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.81e+04 |
# | time/                 |           |
# |    fps                | 253       |
# |    iterations         | 2100      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.0223   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -105      |
# |    value_loss         | 4.39e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.81e+04 |
# | time/                 |           |
# |    fps                | 253       |
# |    iterations         | 2200      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.0132   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -0.466    |
# |    value_loss         | 8.69e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.81e+04 |
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 2300      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.00764  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -0.0906   |
# |    value_loss         | 2.3e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.81e+04 |
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 2400      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.0063   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 0.0224    |
# |    value_loss         | 1.13e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 2500     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.00691 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0249   |
# |    value_loss         | 1.14e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 2600     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.00749 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.146   |
# |    value_loss         | 2.81e+04 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.8e+04  |
# | time/                 |           |
# |    fps                | 252       |
# |    iterations         | 2700      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.0102   |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -0.294    |
# |    value_loss         | 5.79e+04  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 2800     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.0161  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.0667   |
# |    value_loss         | 1.14e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 2900     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.00777 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00801  |
# |    value_loss         | 1.33e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.8e+04  |
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 3000      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00849  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.00885   |
# |    value_loss         | 1.33e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 3100     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.00491 |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0893  |
# |    value_loss         | 3.99e+04 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 3200     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.00547 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0186   |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 3300     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.00689 |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0274  |
# |    value_loss         | 6.9e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | -1.8e+04 |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 3400     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.0048  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00456  |
# |    value_loss         | 1.33e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 3500      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.00581  |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.149    |
# |    value_loss         | 5.78e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 3600      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.0111   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.0427    |
# |    value_loss         | 1.15e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 3700      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.0115   |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -0.113    |
# |    value_loss         | 1.32e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 3800      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.0137   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -0.0616   |
# |    value_loss         | 6.88e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 3900      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.0163   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -0.353    |
# |    value_loss         | 2.8e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 4000      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.0172   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 0.0702    |
# |    value_loss         | 1.16e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 4100      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.00916  |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -0.133    |
# |    value_loss         | 2.02e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 4200      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.00946  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.0398   |
# |    value_loss         | 6.87e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 4300      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.00996  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 0.0374    |
# |    value_loss         | 1.17e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 4400      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.011    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 0.0417    |
# |    value_loss         | 1.17e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 4500      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.00471  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.119    |
# |    value_loss         | 5.77e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 4600      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.00484  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -0.1      |
# |    value_loss         | 5.42e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 4700      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.00525  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -0.0452   |
# |    value_loss         | 6.15e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 4800      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.00572  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 0.0202    |
# |    value_loss         | 1.17e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 4900      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.00731  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -0.141    |
# |    value_loss         | 2.79e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5000      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.00483  |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -0.0539   |
# |    value_loss         | 2.28e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5100      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.00275  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 0.0088    |
# |    value_loss         | 1.18e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.79e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5200      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.00279  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 0.00263   |
# |    value_loss         | 1.33e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5300      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.00335  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -0.0271   |
# |    value_loss         | 6.13e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5400      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.00351  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0.101    |
# |    value_loss         | 8.65e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5500      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -0.00374  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 0.0124    |
# |    value_loss         | 1.19e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 5600      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.00439  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0.0575   |
# |    value_loss         | 2.4e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 5700      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.0052   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | 0.00528   |
# |    value_loss         | 1.33e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 5800      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.00769  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -0.241    |
# |    value_loss         | 8.64e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 5900      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.00722  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | 0.0259    |
# |    value_loss         | 1.19e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6000      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -0.0087   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -0.101    |
# |    value_loss         | 2.27e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6100      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -0.009    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | 0.033     |
# |    value_loss         | 1.2e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6200      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.00586  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0.149    |
# |    value_loss         | 5.75e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 255       |
# |    iterations         | 6300      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.00611  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 0.0214    |
# |    value_loss         | 1.2e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6400      |
# |    time_elapsed       | 124       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.0116   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.233    |
# |    value_loss         | 3.96e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6500      |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.0132   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | 0.0155    |
# |    value_loss         | 1.33e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6600      |
# |    time_elapsed       | 128       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.00784  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -0.069    |
# |    value_loss         | 6.1e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6700      |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.00935  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | 0.0104    |
# |    value_loss         | 1.33e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6800      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.0111   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -0.306    |
# |    value_loss         | 5.74e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 6900      |
# |    time_elapsed       | 134       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -0.00462  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -0.146    |
# |    value_loss         | 1.05e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 7000      |
# |    time_elapsed       | 136       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.00475  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | 0.0162    |
# |    value_loss         | 1.21e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 7100      |
# |    time_elapsed       | 138       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.00503  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 0.0172    |
# |    value_loss         | 1.21e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7200      |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.00541  |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -0.0967   |
# |    value_loss         | 2.77e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7300      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -0.0063   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -0.131    |
# |    value_loss         | 5.39e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7400      |
# |    time_elapsed       | 143       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.00949  |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | 0.0354    |
# |    value_loss         | 1.22e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.78e+04 |
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 7500      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -0.0052   |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# ...
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 17600     |
# |    time_elapsed       | 349       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -0.0367   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17599     |
# |    policy_loss        | -0.177    |
# |    value_loss         | 6.51e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 17700     |
# |    time_elapsed       | 351       |
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -0.0231   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -0.504    |
# |    value_loss         | 2.7e+04   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 17800     |
# |    time_elapsed       | 354       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -0.02     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | 0.0892    |
# |    value_loss         | 1.4e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 17900     |
# |    time_elapsed       | 356       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -0.0139   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -0.207    |
# |    value_loss         | 1.93e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 18000     |
# |    time_elapsed       | 359       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -0.0149   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -0.0602   |
# |    value_loss         | 6.5e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 18100     |
# |    time_elapsed       | 361       |
# |    total_timesteps    | 90500     |
# | train/                |           |
# |    entropy_loss       | -0.0119   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18099     |
# |    policy_loss        | 0.0497    |
# |    value_loss         | 1.4e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.77e+04 |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 18200     |
# |    time_elapsed       | 364       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -0.0141   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | 0.0604    |
# |    value_loss         | 1.4e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 18300     |
# |    time_elapsed       | 366       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -0.0154   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | -0.445    |
# |    value_loss         | 5.62e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 18400     |
# |    time_elapsed       | 368       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -0.0109   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -0.245    |
# |    value_loss         | 5.27e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 18500     |
# |    time_elapsed       | 370       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -0.023    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -0.238    |
# |    value_loss         | 5.75e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 18600     |
# |    time_elapsed       | 371       |
# |    total_timesteps    | 93000     |
# | train/                |           |
# |    entropy_loss       | -0.00859  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18599     |
# |    policy_loss        | 0.0347    |
# |    value_loss         | 1.41e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 18700     |
# |    time_elapsed       | 373       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -0.00921  |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | -0.177    |
# |    value_loss         | 2.69e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 18800     |
# |    time_elapsed       | 375       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -0.0099   |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -0.116    |
# |    value_loss         | 2.19e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 18900     |
# |    time_elapsed       | 377       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -0.0127   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | 0.054     |
# |    value_loss         | 1.42e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19000     |
# |    time_elapsed       | 379       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -0.0131   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | 0.0196    |
# |    value_loss         | 1.35e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19100     |
# |    time_elapsed       | 381       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -0.0143   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -0.131    |
# |    value_loss         | 5.73e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19200     |
# |    time_elapsed       | 383       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.0109   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -0.357    |
# |    value_loss         | 8.46e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19300     |
# |    time_elapsed       | 385       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -0.0132   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | 0.0556    |
# |    value_loss         | 1.42e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19400     |
# |    time_elapsed       | 387       |
# |    total_timesteps    | 97000     |
# | train/                |           |
# |    entropy_loss       | -0.0146   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19399     |
# |    policy_loss        | -0.216    |
# |    value_loss         | 2.31e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19500     |
# |    time_elapsed       | 389       |
# |    total_timesteps    | 97500     |
# | train/                |           |
# |    entropy_loss       | -0.0111   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19499     |
# |    policy_loss        | 0.0164    |
# |    value_loss         | 1.35e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19600     |
# |    time_elapsed       | 391       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -0.00686  |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19599     |
# |    policy_loss        | -0.211    |
# |    value_loss         | 8.45e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19700     |
# |    time_elapsed       | 393       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -0.00743  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | 0.0294    |
# |    value_loss         | 1.43e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19800     |
# |    time_elapsed       | 395       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.00866  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -0.0992   |
# |    value_loss         | 2.18e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 19900     |
# |    time_elapsed       | 397       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -0.0117   |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | 0.0499    |
# |    value_loss         | 1.43e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | -1.76e+04 |
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 20000     |
# |    time_elapsed       | 399       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.0243   |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -0.786    |
# |    value_loss         | 5.6e+04   |
# -------------------------------------

# %% [markdown]
# A2C
# ![image.png](attachment:38a4fe31-93db-40f5-9aaf-a654dd45203c.png)
#
# Average reward after 100000 timesteps = -17600
#
# A2C algorithm stagnates

# %% [markdown]
# ## Comparison

# %% [markdown]
# ![image.png](attachment:f419579e-6628-46bc-b504-e84988b211c7.png)
#
# ![image.png](attachment:30899391-12d9-409a-a371-5a4729e6c37f.png)

# %% [markdown]
# The DQN algorithm was increasing in avereage reward. The PPO and A2C had stagnated in performance.

# %% [markdown]
# ## Environment - 3
#
# Modifying reward functions slightly by providing higher margin for constant power
#
# ### State
#
# The data was modeled to function like an environment where the state space of the agent would be an array consisting of
# - Energy consumption of previous hour
# - Value of the previous hour
#
# ### Action
# Using the given state space, in this environment the agent would be required to predict the fall, rise or constant energy requirement for the next day, giving the agent 3 possible actions - Increase, Decrease and Constant.
#
# ### Reward
# For a correct prediction of the change in power consumption, the agent would be given a reward of +10 whereas a wrong prediction would give the agent a reward of -100.
#
# In cases where the agent chose the action as constant, if the power consumption of next day is within 5%, then the agent is given a positive reward else it is given a negative reward. This condition is represented as follows
#
# $0.95 * Energy_t <= Energy_{t+1}<= 1.05 * Energy_t$
#
# where $t$ is timestep t.

# %%
class PowerPredEnv3(Env):
    def __init__(self):
        self.action_space = Discrete(3) # Increase, Decrease, keep same
        self.observation_space = Box(low=np.array([0,0]), high=np.array([23,63000]), dtype=np.int32) ## [Hour of day, Power in MW]
        self.day = 0 #Current day - Opens the day's CSV file
        self.hour = 0 # Hour - Row number of the CSV
        self.state = [self.hour, pd_refs[self.day].loc[self.hour,"MW"]] ## State of the environment

    def get_current_power(self):
        ## Returns the power consumption of the day stored in self.day
        return pd_refs[self.day].loc[self.hour,"MW"]

    def next_day(self):
        ## Changes the day to next day and checks if all CSV files have been read
        self.day += 1
        if(self.day == 30):
            return True
        self.hour = 0
        self.state = [self.hour, self.get_current_power()]
        return False
        
    def step(self, action):
        actual_power = pd_refs[self.day].loc[self.hour+1,"MW"] # Actual power at hour t+1
        prev_power = self.state[1] # Power of previous day
        done = False
        reward = 0
        ## 0 - Increase, 1 - Decrease, 2 - Same
        if(action == 0):
            if(actual_power > prev_power):
                 ## Correct prediction of increase in power demand
                reward = 10
            else:
                reward = -100
        elif(action == 1):
            if(actual_power < prev_power):
                 ## Correct prediction of decrease in power demand
                reward = 10
            else:
                reward = -100
        elif(action == 2):
             ## Correct prediction of constant power demand
             ## The power is within 5% of the previous day's power consumption
            if(0.92*prev_power < actual_power < 1.08 * prev_power):
                reward = 10
            else:
                reward = -100
        self.hour +=1
        done = False
        if(self.hour == 23):
            ## If all hours of the day are completed, move to next file
            done = self.next_day()
        if not done:
            ## Check if all files are read, if not continue 
            self.state = [self.hour, self.get_current_power()]
        info = {
            "day":self.day+1,
            "reward":reward,
            "hour":self.hour-1,
            "prev":prev_power,
            "predicted":action,
            "actual":actual_power
        }
        return self.state, reward, False, done, info
    
    def render(self):
        pass
    
    def reset(self):
        ## Reset the values
        self.day = 0
        self.hour = 0
        self.state = [self.hour, self.get_current_power()]
        info = {
                    "day":self.day+1,
                    "reward":reward,
                    "hour":self.hour-1,
                    "predicted":action,
                }
        return self.state, info

# %%
env = PowerPredEnv3()

# %% [markdown]
# ## Result using random action selection for 5 episodes

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, _, done, info = env.step(action)
        score += reward
        # if(reward > 0):
        #     print(reward, info)
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-21040
# Episode:2 Score:-19940
# Episode:3 Score:-16640
# Episode:4 Score:-18950
# Episode:5 Score:-19720

# %% [markdown]
# ## PPO

# %%
log_path = os.path.join('Training', 'logs')
model1 = PPO('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model1.learn(total_timesteps=100000)
# Out:
# Logging to Training\logs\PPO_10
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 690       |
# |    ep_rew_mean     | -1.91e+04 |
# | time/              |           |
# |    fps             | 395       |
# |    iterations      | 1         |
# |    time_elapsed    | 5         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.86e+04   |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011559788 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 2.29e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.79e+04    |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0133908875 |
# |    clip_fraction        | 0.197        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+05     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.019       |
# |    value_loss           | 2.13e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 690        |
# |    ep_rew_mean          | -1.69e+04  |
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 4          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01833034 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.983     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.61e+04   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0271    |
# |    value_loss           | 1.52e+05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 690        |
# |    ep_rew_mean          | -1.55e+04  |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 5          |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01626351 |
# |    clip_fraction        | 0.257      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.884     |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.43e+04   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0261    |
# |    value_loss           | 1.11e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.4e+04    |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 6           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011756781 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.94e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 6.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.28e+04   |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 7           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008020442 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 3.12e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -1.17e+04   |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 8           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006719169 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 3.04e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -1.06e+04    |
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 9            |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0048549436 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.19e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0144      |
# |    value_loss           | 1.68e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -9.67e+03   |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 10          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004970927 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.52e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 1.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | -8.77e+03   |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 11          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015277617 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.318      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.31e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 9.2e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -7.92e+03    |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 12           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0048286384 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.151       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.02e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00075      |
# |    value_loss           | 7.64e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -7.22e+03     |
# | time/                   |               |
# |    fps                  | 322           |
# |    iterations           | 13            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00089610956 |
# |    clip_fraction        | 0.0144        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.139        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+03      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00245      |
# |    value_loss           | 8.49e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -6.61e+03    |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 14           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0006020077 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.114       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.1e+03      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 8.33e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -6.08e+03    |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 15           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0012121245 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0988      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 6.75e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 690        |
# |    ep_rew_mean          | -5.57e+03  |
# | time/                   |            |
# |    fps                  | 323        |
# |    iterations           | 16         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00650727 |
# |    clip_fraction        | 0.0082     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0722    |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.55e+03   |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.000602  |
# |    value_loss           | 6.88e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -5.13e+03    |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 17           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 1.799417e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0358      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.03e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -7.88e-05    |
# |    value_loss           | 6.9e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -4.74e+03     |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 18            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 2.5993097e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0327       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.16e+03      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000117     |
# |    value_loss           | 7.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -4.39e+03     |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 19            |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 4.2256463e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0292       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.81e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000169     |
# |    value_loss           | 6.81e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -4.06e+03     |
# | time/                   |               |
# |    fps                  | 325           |
# |    iterations           | 20            |
# |    time_elapsed         | 126           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00048215018 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0238       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.3e+03       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -8.87e-05     |
# |    value_loss           | 6.88e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -3.78e+03     |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 21            |
# |    time_elapsed         | 132           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 7.3487754e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0185       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.67e+03      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -5.21e-05     |
# |    value_loss           | 7.09e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -3.52e+03    |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 22           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 3.202012e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0167      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000112    |
# |    value_loss           | 6.86e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -3.28e+03    |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 23           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 8.639338e-05 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0135      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.82e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00052     |
# |    value_loss           | 6.55e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -3.06e+03    |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 24           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 4.761445e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0132      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.37e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -3.74e-05    |
# |    value_loss           | 6.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.86e+03    |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 25           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 2.692177e-05 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0127      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5e+03      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000215    |
# |    value_loss           | 6.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.68e+03    |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 26           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 3.509692e-05 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0108      |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.81e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000184    |
# |    value_loss           | 6.75e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.5e+03      |
# | time/                   |               |
# |    fps                  | 321           |
# |    iterations           | 27            |
# |    time_elapsed         | 171           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.3419165e-05 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00906      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.8e+03       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000135     |
# |    value_loss           | 6.31e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.34e+03    |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 28           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 9.397714e-06 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00944     |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.62e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -4.6e-05     |
# |    value_loss           | 6.47e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -2.2e+03      |
# | time/                   |               |
# |    fps                  | 320           |
# |    iterations           | 29            |
# |    time_elapsed         | 185           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 5.3981377e-05 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0108       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.61e+03      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -2.71e-05     |
# |    value_loss           | 6.59e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | -2.06e+03    |
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 30           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 2.542301e-05 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0105      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.45e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000246    |
# |    value_loss           | 6.3e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.93e+03     |
# | time/                   |               |
# |    fps                  | 321           |
# |    iterations           | 31            |
# |    time_elapsed         | 197           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 9.5443975e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00949      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.5e+03       |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -2.72e-05     |
# |    value_loss           | 6.32e+03      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.85e+03 |
# | time/                   |           |
# |    fps                  | 321       |
# |    iterations           | 32        |
# |    time_elapsed         | 203       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00921  |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.51e+03  |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -2.94e-10 |
# |    value_loss           | 6.34e+03  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -1.73e+03     |
# | time/                   |               |
# |    fps                  | 321           |
# |    iterations           | 33            |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 4.7116133e-05 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00805      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.17e+03      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.0001       |
# |    value_loss           | 6.35e+03      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | -1.62e+03 |
# | time/                   |           |
# |    fps                  | 321       |
# |    iterations           | 34        |
# |    time_elapsed         | 216       |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00712  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.59e+03  |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -5.56e-10 |
# |    value_loss           | 6.24e+03  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -984          |
# | time/                   |               |
# |    fps                  | 321           |
# |    iterations           | 35            |
# |    time_elapsed         | 223           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 7.7302975e-05 |
# |    clip_fraction        | 0.00132       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00587      |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.58e+03      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000468     |
# |    value_loss           | 6.36e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 690           |
# |    ep_rew_mean          | -373          |
# | time/                   |               |
# |    fps                  | 321           |
# |    iterations           | 36            |
# |    time_elapsed         | 229           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00031416342 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00396      |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.39e+03      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -4.85e-05     |
# |    value_loss           | 6.24e+03      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | 149       |
# | time/                   |           |
# |    fps                  | 321       |
# |    iterations           | 37        |
# |    time_elapsed         | 235       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00219  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.82e+03  |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -3.35e-10 |
# |    value_loss           | 6.19e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 690      |
# |    ep_rew_mean          | 604      |
# | time/                   |          |
# |    fps                  | 320      |
# |    iterations           | 38       |
# |    time_elapsed         | 242      |
# |    total_timesteps      | 77824    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00219 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.6e+03  |
# |    n_updates            | 370      |
# |    policy_gradient_loss | 3.55e-10 |
# |    value_loss           | 6.02e+03 |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 690      |
# |    ep_rew_mean          | 935      |
# | time/                   |          |
# |    fps                  | 320      |
# |    iterations           | 39       |
# |    time_elapsed         | 249      |
# |    total_timesteps      | 79872    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00219 |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.34e+03 |
# |    n_updates            | 380      |
# |    policy_gradient_loss | 8.12e-10 |
# |    value_loss           | 6e+03    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | 1.16e+03  |
# | time/                   |           |
# |    fps                  | 319       |
# |    iterations           | 40        |
# |    time_elapsed         | 256       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00219  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.75e+03  |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -1.69e-10 |
# |    value_loss           | 5.88e+03  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | 1.4e+03      |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 41           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 4.784408e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0021      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.61e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -8.42e-06    |
# |    value_loss           | 5.78e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | 1.56e+03  |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 42        |
# |    time_elapsed         | 269       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00199  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.67e+03  |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -1.37e-09 |
# |    value_loss           | 5.78e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | 1.69e+03  |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 43        |
# |    time_elapsed         | 276       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00199  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.05e+03  |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -1.08e-09 |
# |    value_loss           | 5.91e+03  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | 1.78e+03  |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 44        |
# |    time_elapsed         | 282       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00199  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.32e+03  |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -7.68e-10 |
# |    value_loss           | 6e+03     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 690       |
# |    ep_rew_mean          | 1.82e+03  |
# | time/                   |           |
# |    fps                  | 318       |
# |    iterations           | 45        |
# |    time_elapsed         | 288       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00199  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.6e+03   |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -1.41e-09 |
# |    value_loss           | 6.04e+03  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 690      |
# |    ep_rew_mean          | 1.84e+03 |
# | time/                   |          |
# |    fps                  | 319      |
# |    iterations           | 46       |
# |    time_elapsed         | 295      |
# |    total_timesteps      | 94208    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00199 |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.05e+03 |
# |    n_updates            | 450      |
# |    policy_gradient_loss | 4.74e-10 |
# |    value_loss           | 5.99e+03 |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | 1.87e+03     |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 47           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 1.266686e-05 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00185     |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.91e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -7.44e-06    |
# |    value_loss           | 5.79e+03     |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 690      |
# |    ep_rew_mean          | 1.9e+03  |
# | time/                   |          |
# |    fps                  | 318      |
# |    iterations           | 48       |
# |    time_elapsed         | 309      |
# |    total_timesteps      | 98304    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0017  |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.85e+03 |
# |    n_updates            | 470      |
# |    policy_gradient_loss | 1.36e-09 |
# |    value_loss           | 6.04e+03 |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 690          |
# |    ep_rew_mean          | 1.91e+03     |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 49           |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 1.650938e-05 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00149     |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.58e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -2.29e-05    |
# |    value_loss           | 5.89e+03     |
# ------------------------------------------

# %% [markdown]
# PPO
#
# ![image.png](attachment:a9661434-b138-404a-b8eb-b519341c71ce.png)
#
# Average reward after 100,000 timesteps = 19100

# %% [markdown]
# ## DQN

# %%
model2 = DQN('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model2.learn(total_timesteps = 100000)
# Out:
# Logging to Training\logs\DQN_6
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.02e+04 |
# |    exploration_rate | 0.738     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 7056      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 2760      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.08e+04 |
# |    exploration_rate | 0.476     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 7945      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 5520      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.08e+04 |
# |    exploration_rate | 0.213     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 8196      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 8280      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.09e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 8240      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 11040     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 8459      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 13800     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 8578      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 16560     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 8673      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 19320     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 8700      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 22080     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 8757      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 24840     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 8751      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 27600     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.08e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 8746      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 30360     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.07e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 8792      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 33120     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 8820      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 35880     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 8866      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 38640     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 8884      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 41400     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 8898      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 44160     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 8901      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 46920     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -2.06e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 8901      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 49680     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.97e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 5544      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 52440     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 45.8      |
# |    n_updates        | 609       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.88e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 3890      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 55200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 54.5      |
# |    n_updates        | 1299      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -1.8e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3150     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 57960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 43.2     |
# |    n_updates        | 1989     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.74e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 2694      |
# |    time_elapsed     | 22        |
# |    total_timesteps  | 60720     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 41.1      |
# |    n_updates        | 2679      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.66e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 2354      |
# |    time_elapsed     | 26        |
# |    total_timesteps  | 63480     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 43.5      |
# |    n_updates        | 3369      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.61e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 2105      |
# |    time_elapsed     | 31        |
# |    total_timesteps  | 66240     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 24        |
# |    n_updates        | 4059      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.55e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 1925      |
# |    time_elapsed     | 35        |
# |    total_timesteps  | 69000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 32        |
# |    n_updates        | 4749      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.48e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 1793      |
# |    time_elapsed     | 40        |
# |    total_timesteps  | 71760     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 29.9      |
# |    n_updates        | 5439      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -1.4e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1661     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 74520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 45.3     |
# |    n_updates        | 6129     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.32e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 1563      |
# |    time_elapsed     | 49        |
# |    total_timesteps  | 77280     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 40.5      |
# |    n_updates        | 6819      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.24e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 1483      |
# |    time_elapsed     | 53        |
# |    total_timesteps  | 80040     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 31.8      |
# |    n_updates        | 7509      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.17e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 1416      |
# |    time_elapsed     | 58        |
# |    total_timesteps  | 82800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 39.7      |
# |    n_updates        | 8199      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | -1.1e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1357     |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 85560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 51.2     |
# |    n_updates        | 8889     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -1.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 1311      |
# |    time_elapsed     | 67        |
# |    total_timesteps  | 88320     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 23.2      |
# |    n_updates        | 9579      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -9.48e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 1271      |
# |    time_elapsed     | 71        |
# |    total_timesteps  | 91080     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 47.5      |
# |    n_updates        | 10269     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -8.76e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 136       |
# |    fps              | 1227      |
# |    time_elapsed     | 76        |
# |    total_timesteps  | 93840     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 28.5      |
# |    n_updates        | 10959     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -7.98e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 1192      |
# |    time_elapsed     | 80        |
# |    total_timesteps  | 96600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 26.1      |
# |    n_updates        | 11649     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 690       |
# |    ep_rew_mean      | -7.19e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 1159      |
# |    time_elapsed     | 85        |
# |    total_timesteps  | 99360     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 28.7      |
# |    n_updates        | 12339     |
# -----------------------------------

# %% [markdown]
# DQN
#
# ![image.png](attachment:ef56bcf0-b442-4c65-91c5-7300f54a4642.png)
#
# Average reward after 100,000 timesteps = -7190

# %% [markdown]
# ## A2C

# %%
model3 = A2C('MlpPolicy', env, verbose=1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model3.learn(total_timesteps = 100000)
# Out:
# Logging to Training\logs\A2C_6
# ------------------------------------
# | time/                 |          |
# |    fps                | 291      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.128   |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.717    |
# |    value_loss         | 1.05e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 520       |
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 200       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.0859   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 0.427     |
# |    value_loss         | 1.04e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.18e+03 |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.0538  |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.243    |
# |    value_loss         | 1.04e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.18e+03 |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.0186  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0877  |
# |    value_loss         | 3.1e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.36e+03 |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.019   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0722   |
# |    value_loss         | 1.03e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.46e+03 |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.0157  |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0143   |
# |    value_loss         | 1.33e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.53e+03 |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.0126  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0459   |
# |    value_loss         | 1.01e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.53e+03 |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 800      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.00985 |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0344   |
# |    value_loss         | 1.01e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.58e+03  |
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 900       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.00466  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 0.0146    |
# |    value_loss         | 1e+03     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.64e+03 |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.00434 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0174  |
# |    value_loss         | 7.17e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.64e+03 |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.00394 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.012    |
# |    value_loss         | 994      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.68e+03 |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.0035  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0105   |
# |    value_loss         | 990      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.71e+03  |
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 1300      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.00289  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.00845   |
# |    value_loss         | 984       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.73e+03 |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.00225 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.00831 |
# |    value_loss         | 3.17e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.73e+03 |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.00166 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.00453  |
# |    value_loss         | 973      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.75e+03 |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 1600     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.00125 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.00332  |
# |    value_loss         | 969      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.77e+03  |
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 1700      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.000888 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.00227   |
# |    value_loss         | 964       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.78e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 1800      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.000608 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -0.00197  |
# |    value_loss         | 3.21e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.78e+03  |
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 1900      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.000441 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.00104   |
# |    value_loss         | 953       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.79e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 2000      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.000324 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.000745  |
# |    value_loss         | 948       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.8e+03  |
# | time/                 |          |
# |    fps                | 274      |
# |    iterations         | 2100     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.00024 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.000531 |
# |    value_loss         | 943      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.8e+03   |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 2200      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.000185 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -0.000843 |
# |    value_loss         | 4.74e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.81e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 2300      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.000153 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.00033   |
# |    value_loss         | 934       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.82e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 2400      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.000124 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 0.000263  |
# |    value_loss         | 928       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.83e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 2500      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.000104 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 0.00021   |
# |    value_loss         | 923       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.83e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 2600      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -8.98e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.000183  |
# |    value_loss         | 918       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.83e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 2700      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -7.98e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | 0.000157  |
# |    value_loss         | 914       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.84e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 2800      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -7.05e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.00013   |
# |    value_loss         | 908       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.85e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 2900      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -6.39e-05 |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 2.5e-05   |
# |    value_loss         | 1.34e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.85e+03  |
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 3000      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -5.82e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.000104  |
# |    value_loss         | 899       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.85e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 3100      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -5.38e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 0.000103  |
# |    value_loss         | 894       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.85e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 3200      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -4.98e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | 0.000103  |
# |    value_loss         | 889       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.85e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 3300      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -4.58e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -4.82e-05 |
# |    value_loss         | 2.15e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.86e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 3400      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -4.35e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 7.69e-05  |
# |    value_loss         | 879       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.86e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 3500      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -4.09e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 7.67e-05  |
# |    value_loss         | 874       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.87e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 3600      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -3.85e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 7.65e-05  |
# |    value_loss         | 869       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.87e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 3700      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -3.65e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -0.000111 |
# |    value_loss         | 3.36e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.87e+03  |
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 3800      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -3.41e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 5.07e-05  |
# |    value_loss         | 860       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.87e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 3900      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -3.26e-05 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 5.05e-05  |
# |    value_loss         | 855       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.87e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4000      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -3.13e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 5.04e-05  |
# |    value_loss         | 850       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.87e+03  |
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4100      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -3.02e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | 5.03e-05  |
# |    value_loss         | 846       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.88e+03  |
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4200      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -2.89e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | 8.17e-06  |
# |    value_loss         | 1.35e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.88e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4300      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -2.78e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 5e-05     |
# |    value_loss         | 836       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.88e+03  |
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4400      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -2.67e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 4.98e-05  |
# |    value_loss         | 831       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.88e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4500      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -2.58e-05 |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.000116 |
# |    value_loss         | 4.97e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.88e+03  |
# | time/                 |           |
# |    fps                | 274       |
# |    iterations         | 4600      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -2.48e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 4.96e-05  |
# |    value_loss         | 822       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4700      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -2.39e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 4.94e-05  |
# |    value_loss         | 817       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 4800      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -2.21e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 2.46e-05  |
# |    value_loss         | 812       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 4900      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -2.17e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -7.83e-05 |
# |    value_loss         | 6.92e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 5000      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -2.11e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | 2.45e-05  |
# |    value_loss         | 803       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 5100      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.06e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 2.44e-05  |
# |    value_loss         | 798       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5200      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -2.02e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 2.44e-05  |
# |    value_loss         | 794       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5300      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -1.98e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 2.43e-05  |
# |    value_loss         | 790       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5400      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -1.93e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -7.86e-05 |
# |    value_loss         | 6.97e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.89e+03  |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5500      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.89e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 2.41e-05  |
# |    value_loss         | 780       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5600      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.85e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -3.87e-05 |
# |    value_loss         | 7.64e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5700      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -1.81e-05 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | 2.4e-05   |
# |    value_loss         | 771       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5800      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -1.77e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -7.89e-05 |
# |    value_loss         | 7.02e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 5900      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -1.74e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | 2.39e-05  |
# |    value_loss         | 762       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 6000      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -1.71e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -8.03e-05 |
# |    value_loss         | 1.46e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 6100      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -1.67e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | 2.37e-05  |
# |    value_loss         | 753       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 6200      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -1.64e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | 2.36e-05  |
# |    value_loss         | 748       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 6300      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -1.61e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 2.36e-05  |
# |    value_loss         | 744       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 6400      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -1.58e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.000121 |
# |    value_loss         | 2.21e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 6500      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -1.54e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | 2.34e-05  |
# |    value_loss         | 735       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 6600      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -1.51e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | 2.34e-05  |
# |    value_loss         | 731       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.9e+03   |
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 6700      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -1.49e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | 2.33e-05  |
# |    value_loss         | 727       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.91e+03  |
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 6800      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -1.46e-05 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -0.000162 |
# |    value_loss         | 3.02e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.91e+03  |
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 6900      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -1.43e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | 2.32e-05  |
# |    value_loss         | 717       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.91e+03 |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 7000     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -1.4e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 2.31e-05 |
# |    value_loss         | 713      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.91e+03  |
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 7100      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -1.38e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 2.3e-05   |
# |    value_loss         | 709       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.91e+03  |
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 7200      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -1.35e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | 2.29e-05  |
# |    value_loss         | 704       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.91e+03  |
# | time/                 |           |
# |    fps                | 270       |
# |    iterations         | 7300      |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -1.32e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -3.94e-05 |
# |    value_loss         | 3.66e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.91e+03 |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 7400     |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -1.3e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 2.28e-05 |
# |    value_loss         | 696      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.91e+03  |
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 7500      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -1.28e-05 |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# ...
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 17600     |
# |    time_elapsed       | 352       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -6.39e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17599     |
# |    policy_loss        | -0        |
# |    value_loss         | 368       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 17700     |
# |    time_elapsed       | 355       |
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -6.37e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -0        |
# |    value_loss         | 365       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 17800     |
# |    time_elapsed       | 357       |
# |    total_timesteps    | 89000     |
# | train/                |           |
# |    entropy_loss       | -6.36e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17799     |
# |    policy_loss        | -0        |
# |    value_loss         | 362       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 17900     |
# |    time_elapsed       | 359       |
# |    total_timesteps    | 89500     |
# | train/                |           |
# |    entropy_loss       | -6.34e-06 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17899     |
# |    policy_loss        | -0        |
# |    value_loss         | 360       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 18000     |
# |    time_elapsed       | 361       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -6.33e-06 |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.53e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 18100     |
# |    time_elapsed       | 363       |
# |    total_timesteps    | 90500     |
# | train/                |           |
# |    entropy_loss       | -6.31e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18099     |
# |    policy_loss        | -0        |
# |    value_loss         | 355       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 18200     |
# |    time_elapsed       | 365       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -6.29e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -0        |
# |    value_loss         | 352       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 18300     |
# |    time_elapsed       | 367       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -6.28e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | -0        |
# |    value_loss         | 6.33e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 18400     |
# |    time_elapsed       | 369       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -6.27e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -0        |
# |    value_loss         | 347       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 18500     |
# |    time_elapsed       | 372       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -6.25e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | -0        |
# |    value_loss         | 345       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 18600     |
# |    time_elapsed       | 374       |
# |    total_timesteps    | 93000     |
# | train/                |           |
# |    entropy_loss       | -6.24e-06 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18599     |
# |    policy_loss        | -0        |
# |    value_loss         | 343       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 18700     |
# |    time_elapsed       | 376       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -6.22e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | -0        |
# |    value_loss         | 8.39e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 18800     |
# |    time_elapsed       | 378       |
# |    total_timesteps    | 94000     |
# | train/                |           |
# |    entropy_loss       | -6.21e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18799     |
# |    policy_loss        | -0        |
# |    value_loss         | 337       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 18900     |
# |    time_elapsed       | 381       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | -6.19e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -0        |
# |    value_loss         | 335       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 19000     |
# |    time_elapsed       | 382       |
# |    total_timesteps    | 95000     |
# | train/                |           |
# |    entropy_loss       | -6.18e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18999     |
# |    policy_loss        | -0        |
# |    value_loss         | 333       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 19100     |
# |    time_elapsed       | 384       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | -6.16e-06 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -0        |
# |    value_loss         | 330       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 19200     |
# |    time_elapsed       | 387       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -6.15e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -0        |
# |    value_loss         | 8.44e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 19300     |
# |    time_elapsed       | 389       |
# |    total_timesteps    | 96500     |
# | train/                |           |
# |    entropy_loss       | -6.13e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19299     |
# |    policy_loss        | -0        |
# |    value_loss         | 325       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 19400     |
# |    time_elapsed       | 391       |
# |    total_timesteps    | 97000     |
# | train/                |           |
# |    entropy_loss       | -6.12e-06 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19399     |
# |    policy_loss        | -0        |
# |    value_loss         | 9.01e+03  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 690      |
# |    ep_rew_mean        | 1.95e+03 |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 19500    |
# |    time_elapsed       | 393      |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | -6.1e-06 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | -0       |
# |    value_loss         | 321      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 19600     |
# |    time_elapsed       | 395       |
# |    total_timesteps    | 98000     |
# | train/                |           |
# |    entropy_loss       | -6.09e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19599     |
# |    policy_loss        | -0        |
# |    value_loss         | 8.48e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 19700     |
# |    time_elapsed       | 397       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | -6.08e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -0        |
# |    value_loss         | 316       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 19800     |
# |    time_elapsed       | 399       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -6.06e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -0        |
# |    value_loss         | 1.68e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 19900     |
# |    time_elapsed       | 401       |
# |    total_timesteps    | 99500     |
# | train/                |           |
# |    entropy_loss       | -6.05e-06 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19899     |
# |    policy_loss        | -0        |
# |    value_loss         | 311       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 690       |
# |    ep_rew_mean        | 1.95e+03  |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 20000     |
# |    time_elapsed       | 403       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -6.03e-06 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -0        |
# |    value_loss         | 309       |
# -------------------------------------

# %% [markdown]
# A2C
#
# ![image.png](attachment:0f46f98f-e4a9-498d-a7cb-c5d7b99ae6c6.png)
#
# Average reward after 100,000 timesteps = 1950

# %% [markdown]
# ## Comparison

# %% [markdown]
# ![image.png](attachment:11ea39c3-9724-46a6-869a-da9567f07b1d.png)

# %% [markdown]
# ![image.png](attachment:233c7c4e-3089-442b-836f-94c2cc6b4b0d.png)
#
# The DQN algorithm was not able to converge as fast as the PPO and A2C algorithms, with DQN getting negative average rewards while the other algorithms got a positive reward after 100,000 steps
